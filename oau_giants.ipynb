# %% [markdown]
# # Importing Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# # Display all columns and rows with cell contents
# with pd.option_context('display.colheader_justify', 'left'):
#     print(df)

# %% [markdown]
# # Viewing Dataframes

# %% [markdown]
# ***Viewing Dataframes***

# %%
with open ('OAUGIANTS_GAMES_2001_TO_2022_METADATA.txt') as file:
    metadata = file.read()
    print(metadata)
# Out:
# These datasets were collated and compiled by AlliNewsNigeria..
# "AlliNewsNigeria is a sports brand that majors in collegiate sports.
# The brand is actively involved in sports media and sports data management activities."
# DATASET ONE: OAUGIANTS_GAMES_2001_TO_2022
# DATASET DESCRIPTION
# "This dataset was collated and compiled by AlliNewsNigeria.
# Dataset contains basic details of major football matches played by the Male Team of the Obafemi Awolowo University between 2001-2022.
# Please refer to the metadata attached to this dataset and saved as a *.txt document for background information on the dataset.
# This dataset may be missing some parts so, kindly send a mail to allinewsnigeria@gmail.com to get an updated version."
# DATA SOURCES
# "The data was compiled from a variety of trusted sources and carefully vetted and  inspected.
# Compilation process featured physical and online interviews, a vast amount of online sources
# ...

# %%
giants_df = pd.read_csv('OAUGIANTS_GAMES_2001_TO_2022_RESULT_SHEET.csv')
giants_df
# Out:
#                                            Unnamed: 0      Date  \
# 0   This dataset was collated and compiled by Alli...       NaN
# 1                                                   1  20030000
# 2                                                   2  20030000
# 3                                                   3  20030000
# 4                                                   4  20030000
# 5                                                   5  20030000
# 6                                                   6  20030000
# 7                                                   7  20040000
# 8                                                   8  20040000
# 9                                                   9  20040000
# 10                                                 10  20050000
# 11                                                 11  20050000
# 12                                                 12  20050000
# 13                                                 13  20050000
# ...

# %%
len(giants_df)
giants_df.MatchRemarks.value_counts()
# Out:
# Approved        69
# Abandoned        1
# Inconclusive     1
# Anulled          1
# No Contest       1
# Postponed        1
# Name: MatchRemarks, dtype: int64

# %% [markdown]
# # DATA WRANGLING
# Inspect dataset visually & programmatically for *structural* and *tidiness* issues.

# %% [markdown]
# **Correcting Goalscorer**
# - *Taofeek Yekini Olanrewaju was the actual goalscorer of the freekick against Unilag at NUGA 2022 and so it needs correction!* How to use [df.at()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.at.html) and here's [more info](https://re-thought.com/how-to-change-or-update-a-cell-value-in-python-pandas-dataframe/) on df.at()

# %%
#Changing Goalscorer Name 
giants_df.at[66, 'GScorers(Info)'] = 'Taofeek Yekini(2ndhalf/leftfoot-freekick)'
giants_df
# Out:
#                                            Unnamed: 0      Date  \
# 0   This dataset was collated and compiled by Alli...       NaN
# 1                                                   1  20030000
# 2                                                   2  20030000
# 3                                                   3  20030000
# 4                                                   4  20030000
# 5                                                   5  20030000
# 6                                                   6  20030000
# 7                                                   7  20040000
# 8                                                   8  20040000
# 9                                                   9  20040000
# 10                                                 10  20050000
# 11                                                 11  20050000
# 12                                                 12  20050000
# 13                                                 13  20050000
# ...

# %% [markdown]
# **. Making the name of the desired team (OAU Male Football Team) uniform**
# - *Correct the name used to refer to the Obafemi Awolowo University Male team for uniformity.* How to use [df.replace()](ttps://datatofish.com/replace-values-pandas-dataframe/)

# %%
# Replace Values Across and Entire DataFrame
giants_df = giants_df.replace(to_replace='OAU', value='OAU Giants')
giants_df
# Out:
#                                            Unnamed: 0      Date  \
# 0   This dataset was collated and compiled by Alli...       NaN
# 1                                                   1  20030000
# 2                                                   2  20030000
# 3                                                   3  20030000
# 4                                                   4  20030000
# 5                                                   5  20030000
# 6                                                   6  20030000
# 7                                                   7  20040000
# 8                                                   8  20040000
# 9                                                   9  20040000
# 10                                                 10  20050000
# 11                                                 11  20050000
# 12                                                 12  20050000
# 13                                                 13  20050000
# ...

# %% [markdown]
# **Correcting data Entry errors in Competition column**
# - *2007 NUGA Games were in UNN.*
# - *Unilag NUGA Games should be in 2022*
#
# How to use [df.replace()](ttps://datatofish.com/replace-values-pandas-dataframe/)

# %%
# Correcting the entry errors in the 'Competition' column
giants_df['Competition'] = giants_df['Competition'].replace(['2014 NUGA Games (Unimaid 2007)'], 
                                                             '2007 NUGA Games (Unimaid 2007)')

giants_df['Competition'] = giants_df['Competition'].replace(['2018 NUGA Games (Unilag 2022)',
                                                             '2019 NUGA Games (Unilag 2022)', 
                                                             '2020 NUGA Games (Unilag 2022)',
                                                             '2021 NUGA Games (Unilag 2022)', 
                                                             '2023 NUGA Games (Unilag 2022)'], 
                                                             '2022 NUGA Games (Unilag 2022)')
giants_df
# Out:
#                                            Unnamed: 0      Date  \
# 0   This dataset was collated and compiled by Alli...       NaN
# 1                                                   1  20030000
# 2                                                   2  20030000
# 3                                                   3  20030000
# 4                                                   4  20030000
# 5                                                   5  20030000
# 6                                                   6  20030000
# 7                                                   7  20040000
# 8                                                   8  20040000
# 9                                                   9  20040000
# 10                                                 10  20050000
# 11                                                 11  20050000
# 12                                                 12  20050000
# 13                                                 13  20050000
# ...

# %% [markdown]
# ***Copying dataframe for cleaning***

# %%
#Creating copy for data cleaning
giants_copy = giants_df.copy()

# %%
giants_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      75 non-null     object
#  1   Date            74 non-null     object
#  2   Venue           74 non-null     object
#  3   Time            74 non-null     object
#  4   MatchID         74 non-null     float64
#  5   Competition     74 non-null     object
#  6   Grouping        74 non-null     object
#  7   Format          74 non-null     object
#  8   Tie             74 non-null     object
#  9   TieDescr        74 non-null     object
#  10  HomeTeam        74 non-null     object
#  11  AwayTeam        74 non-null     object
#  12  HTHG            74 non-null     object
#  13  HTAG            74 non-null     object
#  14  FTHG            74 non-null     object
#  15  FTAG            74 non-null     object
#  16  AETHG           74 non-null     object
# ...

# %% [markdown]
# *Removing the first row with the compilation info*

# %%
giants_copy = giants_copy.drop([0])
giants_copy.head()
# Out:
#   Unnamed: 0      Date          Venue Time   MatchID Competition Grouping  \
# 1          1  20030000   Futo, Owerri    -  773855.0   2nd NUFOL        -
# 2          2  20030000   Futo, Owerri    -  952508.0   2nd NUFOL        -
# 3          3  20030000      Buk, Kano    -  693075.0   2nd NUFOL        -
# 4          4  20030000      Buk, Kano    -  657312.0   2nd NUFOL        -
# 5          5  20030000  Unilag, Lagos    -  387287.0   2nd NUFOL        -
#
#        Format      Tie TieDescr    HomeTeam AwayTeam HTHG HTAG FTHG FTAG  \
# 1  Tournament  Prelims      MD1  OAU Giants  LAUTECH    1    0    1    0
# 2  Tournament  Prelims      MD2  OAU Giants     FUTA    3    1    5    2
# 3  Tournament  Round 2      MD3  OAU Giants      UNN    0    0    0    0
# 4  Tournament  Round 2      MD4  OAU Giants     FUTO    1    1    2    1
# 5  Tournament       SF      MD5  OAU Giants      ABU    1    1    1    2
#
#   AETHG AETAG PENHG PENAG FORM MatchRemarks  \
# ...

# %%
giants_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 1 to 74
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      74 non-null     object
#  1   Date            74 non-null     object
#  2   Venue           74 non-null     object
#  3   Time            74 non-null     object
#  4   MatchID         74 non-null     float64
#  5   Competition     74 non-null     object
#  6   Grouping        74 non-null     object
#  7   Format          74 non-null     object
#  8   Tie             74 non-null     object
#  9   TieDescr        74 non-null     object
#  10  HomeTeam        74 non-null     object
#  11  AwayTeam        74 non-null     object
#  12  HTHG            74 non-null     object
#  13  HTAG            74 non-null     object
#  14  FTHG            74 non-null     object
#  15  FTAG            74 non-null     object
#  16  AETHG           74 non-null     object
# ...

# %% [markdown]
# *Dropping un-needed columns*

# %%
giants_copy = giants_copy.drop(columns=['Unnamed: 0', 'AETHG', 'AETAG'])
giants_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 1 to 74
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            74 non-null     object
#  1   Venue           74 non-null     object
#  2   Time            74 non-null     object
#  3   MatchID         74 non-null     float64
#  4   Competition     74 non-null     object
#  5   Grouping        74 non-null     object
#  6   Format          74 non-null     object
#  7   Tie             74 non-null     object
#  8   TieDescr        74 non-null     object
#  9   HomeTeam        74 non-null     object
#  10  AwayTeam        74 non-null     object
#  11  HTHG            74 non-null     object
#  12  HTAG            74 non-null     object
#  13  FTHG            74 non-null     object
#  14  FTAG            74 non-null     object
#  15  PENHG           74 non-null     object
#  16  PENAG           74 non-null     object
# ...

# %% [markdown]
# *Convert MatchID column to string since it's only an identification detail!*

# %%
giants_copy['MatchID'] = giants_copy['MatchID'].astype(str)

# %% [markdown]
# *replacing all - entries with NaN for easy cleaning*

# %%
giants_copy = giants_copy.replace(to_replace='-', value= np.nan)
giants_copy
# Out:
#         Date                             Venue      Time   MatchID  \
# 1   20030000                      Futo, Owerri       NaN  773855.0
# 2   20030000                      Futo, Owerri       NaN  952508.0
# 3   20030000                         Buk, Kano       NaN  693075.0
# 4   20030000                         Buk, Kano       NaN  657312.0
# 5   20030000                     Unilag, Lagos       NaN  387287.0
# 6   20030000                               NaN       NaN  516262.0
# 7   20040000                             Benin       NaN  563037.0
# 8   20040000                             Benin       NaN  793575.0
# 9   20040000                              Eksu       NaN  669888.0
# 10  20050000  Igbinedion University Okada town       NaN  366438.0
# 11  20050000  Igbinedion University Okada town       NaN  700535.0
# 12  20050000  Igbinedion University Okada town       NaN  540983.0
# 13  20050000  Igbinedion University Okada town       NaN  560271.0
# ...

# %% [markdown]
# HTHG, HTAG, FTHG, FTAG, PENHG, PENAG should all be integers
#
# [How to Convert Multiple Pandas DataFrame Columns to int](https://www.statology.org/pandas-convert-column-to-int/)

# %%
giants_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 1 to 74
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            73 non-null     object
#  1   Venue           73 non-null     object
#  2   Time            40 non-null     object
#  3   MatchID         74 non-null     object
#  4   Competition     74 non-null     object
#  5   Grouping        55 non-null     object
#  6   Format          73 non-null     object
#  7   Tie             71 non-null     object
#  8   TieDescr        73 non-null     object
#  9   HomeTeam        74 non-null     object
#  10  AwayTeam        74 non-null     object
#  11  HTHG            70 non-null     object
#  12  HTAG            70 non-null     object
#  13  FTHG            72 non-null     object
#  14  FTAG            72 non-null     object
#  15  PENHG           9 non-null      object
#  16  PENAG           9 non-null      object
# ...

# %% [markdown]
# [getting row indexes](https://www.geeksforgeeks.org/how-to-drop-rows-in-dataframe-by-conditions-on-column-values/)

# %%
# get the row indexes where MatchRemarks is not 'Approved'
row_index = giants_copy[giants_copy['MatchRemarks'] != 'Approved'].index
  
# drop these row indexes from dataFrame
giants_copy.drop(row_index, inplace = True)
giants_copy
# Out:
#         Date                             Venue      Time   MatchID  \
# 1   20030000                      Futo, Owerri       NaN  773855.0
# 2   20030000                      Futo, Owerri       NaN  952508.0
# 3   20030000                         Buk, Kano       NaN  693075.0
# 4   20030000                         Buk, Kano       NaN  657312.0
# 5   20030000                     Unilag, Lagos       NaN  387287.0
# 6   20030000                               NaN       NaN  516262.0
# 7   20040000                             Benin       NaN  563037.0
# 8   20040000                             Benin       NaN  793575.0
# 10  20050000  Igbinedion University Okada town       NaN  366438.0
# 11  20050000  Igbinedion University Okada town       NaN  700535.0
# 12  20050000  Igbinedion University Okada town       NaN  540983.0
# 13  20050000  Igbinedion University Okada town       NaN  560271.0
# 14  20050000  Igbinedion University Okada town       NaN  554226.0
# ...

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

giants_copy.info()
giants_copy.shape
giants_copy.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69 entries, 1 to 74
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            68 non-null     object
#  1   Venue           68 non-null     object
#  2   Time            37 non-null     object
#  3   MatchID         69 non-null     object
#  4   Competition     69 non-null     object
#  5   Grouping        51 non-null     object
#  6   Format          69 non-null     object
#  7   Tie             67 non-null     object
#  8   TieDescr        69 non-null     object
#  9   HomeTeam        69 non-null     object
#  10  AwayTeam        69 non-null     object
#  11  HTHG            67 non-null     object
#  12  HTAG            67 non-null     object
#  13  FTHG            69 non-null     object
#  14  FTAG            69 non-null     object
#  15  PENHG           9 non-null      object
#  16  PENAG           9 non-null      object
# ...

# %% [markdown]
# There's need to convert to score columns to integers but the NaNs wouldn't permit such conversion and it returns a ValueError that can be handled using [any of these methods](https://www.geeksforgeeks.org/how-to-fix-valueerror-cannot-convert-float-nan-to-integer/). On visual inspecton, the columns containing the NaNs are walkover wins/loss for the OAU Giants.
#
# - Replace all NaN entries in these columns with 0
# - Change the remarks of Walkover columns to *'Walkover'* instead of *'Approved'* to distinguish them.

# %%
#replacing NaN values in the score columns
giants_copy[['HTHG','HTAG','FTHG','FTAG','PENHG','PENAG']] = giants_copy[['HTHG','HTAG','FTHG','FTAG','PENHG','PENAG']].fillna(0)
giants_copy
# Out:
#         Date                             Venue      Time   MatchID  \
# 1   20030000                      Futo, Owerri       NaN  773855.0
# 2   20030000                      Futo, Owerri       NaN  952508.0
# 3   20030000                         Buk, Kano       NaN  693075.0
# 4   20030000                         Buk, Kano       NaN  657312.0
# 5   20030000                     Unilag, Lagos       NaN  387287.0
# 6   20030000                               NaN       NaN  516262.0
# 7   20040000                             Benin       NaN  563037.0
# 8   20040000                             Benin       NaN  793575.0
# 10  20050000  Igbinedion University Okada town       NaN  366438.0
# 11  20050000  Igbinedion University Okada town       NaN  700535.0
# 12  20050000  Igbinedion University Okada town       NaN  540983.0
# 13  20050000  Igbinedion University Okada town       NaN  560271.0
# 14  20050000  Igbinedion University Okada town       NaN  554226.0
# ...

# %%
#indicating Walkover win/loss
giants_copy.at[19, 'MatchRemarks'] = 'Walkover'
giants_copy.at[74, 'MatchRemarks'] = 'Walkover'

giants_copy
# Out:
#         Date                             Venue      Time   MatchID  \
# 1   20030000                      Futo, Owerri       NaN  773855.0
# 2   20030000                      Futo, Owerri       NaN  952508.0
# 3   20030000                         Buk, Kano       NaN  693075.0
# 4   20030000                         Buk, Kano       NaN  657312.0
# 5   20030000                     Unilag, Lagos       NaN  387287.0
# 6   20030000                               NaN       NaN  516262.0
# 7   20040000                             Benin       NaN  563037.0
# 8   20040000                             Benin       NaN  793575.0
# 10  20050000  Igbinedion University Okada town       NaN  366438.0
# 11  20050000  Igbinedion University Okada town       NaN  700535.0
# 12  20050000  Igbinedion University Okada town       NaN  540983.0
# 13  20050000  Igbinedion University Okada town       NaN  560271.0
# 14  20050000  Igbinedion University Okada town       NaN  554226.0
# ...

# %%
#removing the extra bit from the match ID
giants_copy['MatchID'] = giants_copy['MatchID'].str.replace(r'\.\d*', '');
giants_copy;
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20136\106773366.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   giants_copy['MatchID'] = giants_copy['MatchID'].str.replace(r'\.\d*', '');

# %%
giants_copy.Competition.value_counts()
# Out:
# 2019 Higher Institutions' Football League        7
# 2nd NUFOL                                        6
# Prof. Adedoyin Peace Cup                         6
# 2022 NUGA Games (Unilag 2022)                    6
# 2022 Higher Institutions' Football League        6
# 2007 NUGA Games (Unimaid 2007)                   6
# 2014 NUGA Games (Oau 2014)                       5
# 2018 Higher Institutions' Football League        5
# 4th NUFOL                                        5
# 2011 NUGA Games (Uniben 2011)                    3
# 2016 PreNUGA                                     3
# 2010 PreNUGA                                     2
# 3rd NUFOL                                        2
# 2021 Higher Institutions' Football League        2
# 2022 PreNUGA                                     2
# 2015 West African University Games (Unn 2015)    2
# 2006 PreNUGA                                     1
# Name: Competition, dtype: int64

# %% [markdown]
# Makes more sense to group by Competition and create a CompID for ease of analysis.
# - create a column CompGroup
# - create column CompID
#   - generate unique ID for each CompGroup

# %%
# Creating Groups/Classification for all competitions
conditions = [ 
  #HiFL
  ((giants_copy['Competition']=="2018 Higher Institutions' Football League") | (giants_copy['Competition']=="2019 Higher Institutions' Football League") | (giants_copy['Competition']=="2021 Higher Institutions' Football League") | (giants_copy['Competition']=="2022 Higher Institutions' Football League")), 
  #NUFOL Games
  ((giants_copy['Competition']=='2nd NUFOL') | (giants_copy['Competition']=='3rd NUFOL') | (giants_copy['Competition']=='4th NUFOL')), 
  #NUGA Games
  ((giants_copy['Competition']=='2007 NUGA Games (Unimaid 2007)') | (giants_copy['Competition']=='2011 NUGA Games (Uniben 2011)') | (giants_copy['Competition']=='2014 NUGA Games (Oau 2014)') | (giants_copy['Competition']=='2022 NUGA Games (Unilag 2022)')), 
  #Peace Cup
  (giants_copy['Competition']=='Prof. Adedoyin Peace Cup'), 
  #PreNUGA
  ((giants_copy['Competition']=='2006 PreNUGA') | (giants_copy['Competition']=='2010 PreNUGA') | (giants_copy['Competition']=='2016 PreNUGA') | (giants_copy['Competition']=='2022 PreNUGA')), 
  #WAUG
  (giants_copy['Competition']=='2015 West African University Games (Unn 2015)'), 
  ]

values = ['HiFL', 'NUFOL Games', 'NUGA Games', 'Peace Cup', 'PreNUGA', 'WAUG'] #arranged alphabetically

giants_copy['CompGroup'] = np.select(conditions, values)
giants_copy.info()
giants_copy
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69 entries, 1 to 74
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            68 non-null     object
#  1   Venue           68 non-null     object
#  2   Time            37 non-null     object
#  3   MatchID         69 non-null     object
#  4   Competition     69 non-null     object
#  5   Grouping        51 non-null     object
#  6   Format          69 non-null     object
#  7   Tie             67 non-null     object
#  8   TieDescr        69 non-null     object
#  9   HomeTeam        69 non-null     object
#  10  AwayTeam        69 non-null     object
#  11  HTHG            69 non-null     object
#  12  HTAG            69 non-null     object
#  13  FTHG            69 non-null     object
#  14  FTAG            69 non-null     object
#  15  PENHG           69 non-null     object
#  16  PENAG           69 non-null     object
# ...

# %%
giants_copy['CompGroup'].unique().tolist()
# Out:
# ['NUFOL Games', 'PreNUGA', 'NUGA Games', 'WAUG', 'HiFL', 'Peace Cup']

# %% [markdown]
# - 29832	HiFL
# - 29539	NUFOL Games
# - 29200	NUGA Games
# - 29175	Peace Cup
# - 29108	PreNUGA
# - 29058	WAUG

# %%
# Creating unique IDs for each Competition
conditions = [ 
  #HiFL
  (giants_copy['CompGroup']=="HiFL"), 
  #NUFOL Games
  (giants_copy['CompGroup']=='NUFOL Games'), 
  #NUGA Games
  (giants_copy['CompGroup']=='NUGA Games'), 
  #Peace Cup
  (giants_copy['CompGroup']=='Peace Cup'), 
  #PreNUGA
  (giants_copy['CompGroup']=='PreNUGA'), 
  #WAUG
  (giants_copy['CompGroup']=='WAUG'), 
  ]

values = ['29832', '29539', '29200', '29175', '29108', '29058'] #as obtained from AlliNews Competition Table

giants_copy['CompID'] = np.select(conditions, values)
giants_copy.info()
giants_copy
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69 entries, 1 to 74
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            68 non-null     object
#  1   Venue           68 non-null     object
#  2   Time            37 non-null     object
#  3   MatchID         69 non-null     object
#  4   Competition     69 non-null     object
#  5   Grouping        51 non-null     object
#  6   Format          69 non-null     object
#  7   Tie             67 non-null     object
#  8   TieDescr        69 non-null     object
#  9   HomeTeam        69 non-null     object
#  10  AwayTeam        69 non-null     object
#  11  HTHG            69 non-null     object
#  12  HTAG            69 non-null     object
#  13  FTHG            69 non-null     object
#  14  FTAG            69 non-null     object
#  15  PENHG           69 non-null     object
#  16  PENAG           69 non-null     object
# ...

# %%
#Changing Date to 2019XXXX for OAU Giants versus Sabo Strikers 
#since we are sure it was played in 2019
giants_copy.at[45, 'Date'] = '20190000'
giants_copy.info()
giants_copy
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69 entries, 1 to 74
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            69 non-null     object
#  1   Venue           68 non-null     object
#  2   Time            37 non-null     object
#  3   MatchID         69 non-null     object
#  4   Competition     69 non-null     object
#  5   Grouping        51 non-null     object
#  6   Format          69 non-null     object
#  7   Tie             67 non-null     object
#  8   TieDescr        69 non-null     object
#  9   HomeTeam        69 non-null     object
#  10  AwayTeam        69 non-null     object
#  11  HTHG            69 non-null     object
#  12  HTAG            69 non-null     object
#  13  FTHG            69 non-null     object
#  14  FTAG            69 non-null     object
#  15  PENHG           69 non-null     object
#  16  PENAG           69 non-null     object
# ...

# %%
#Changing Venue to Unilag, Lagos for OAU Giants versus UNILAG
#on the assumption that the third-place match couldn't have been moved elsewhere 
#it's a safe guess, since the semis also happened in Lagos

giants_copy.at[6, 'Venue'] = 'Unilag, Lagos'
giants_copy.info()
giants_copy
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69 entries, 1 to 74
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            69 non-null     object
#  1   Venue           69 non-null     object
#  2   Time            37 non-null     object
#  3   MatchID         69 non-null     object
#  4   Competition     69 non-null     object
#  5   Grouping        51 non-null     object
#  6   Format          69 non-null     object
#  7   Tie             67 non-null     object
#  8   TieDescr        69 non-null     object
#  9   HomeTeam        69 non-null     object
#  10  AwayTeam        69 non-null     object
#  11  HTHG            69 non-null     object
#  12  HTAG            69 non-null     object
#  13  FTHG            69 non-null     object
#  14  FTAG            69 non-null     object
#  15  PENHG           69 non-null     object
#  16  PENAG           69 non-null     object
# ...

# %%
#input goalscorer info for OAU Giants vs AAUA Luminaries 
#at 2021 Higher Institutions' Football League
#correct entry schould be Olaniyi Muyiwa who scored a second-half penalty kick
#in the 46th minute
giants_copy.at[59,'GScorers(Info)'] = 'Olaniyi Muyiwa(46min/rightfoot-penalty)'

# %%
giants_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69 entries, 1 to 74
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            69 non-null     object
#  1   Venue           69 non-null     object
#  2   Time            37 non-null     object
#  3   MatchID         69 non-null     object
#  4   Competition     69 non-null     object
#  5   Grouping        51 non-null     object
#  6   Format          69 non-null     object
#  7   Tie             67 non-null     object
#  8   TieDescr        69 non-null     object
#  9   HomeTeam        69 non-null     object
#  10  AwayTeam        69 non-null     object
#  11  HTHG            69 non-null     object
#  12  HTAG            69 non-null     object
#  13  FTHG            69 non-null     object
#  14  FTAG            69 non-null     object
#  15  PENHG           69 non-null     object
#  16  PENAG           69 non-null     object
# ...

# %%
#change time to 24hr format
giants_copy['Time24h'] = pd.to_datetime(giants_copy['Time'], format='%I:%M %p').dt.strftime('%H:%M')
giants_copy
# Out:
#         Date                             Venue      Time MatchID  \
# 1   20030000                      Futo, Owerri       NaN  773855
# 2   20030000                      Futo, Owerri       NaN  952508
# 3   20030000                         Buk, Kano       NaN  693075
# 4   20030000                         Buk, Kano       NaN  657312
# 5   20030000                     Unilag, Lagos       NaN  387287
# 6   20030000                     Unilag, Lagos       NaN  516262
# 7   20040000                             Benin       NaN  563037
# 8   20040000                             Benin       NaN  793575
# 10  20050000  Igbinedion University Okada town       NaN  366438
# 11  20050000  Igbinedion University Okada town       NaN  700535
# 12  20050000  Igbinedion University Okada town       NaN  540983
# 13  20050000  Igbinedion University Okada town       NaN  560271
# 14  20050000  Igbinedion University Okada town       NaN  554226
# ...

# %%
giants_copy.Venue.value_counts()
# Out:
# Unilag Sports Center, Akoka         11
# OAU Sports Complex, Ile-Ife          8
# Maiduguri                            6
# Benin                                5
# Igbinedion University Okada town     5
# Mainbowl, Oau Sports Complex         5
# Oduduwa College, Ile-Ife             4
# Kwasu, Malete, Kwara                 3
# Futo, Owerri                         2
# Buk, Kano                            2
# Agege Stadium, Lagos                 2
# UI Sports Complex, Ibadan            2
# Unn, Nsukka                          2
# OAU, Ile-Ife                         2
# Unilag, Lagos                        2
# Uam Sports Complex, Makurdi          1
# Ilorin, Kwara                        1
# Ife Grammar School, Ile-Ife          1
# LASU Sports Center, Iyana-Iba        1
# UAM Sports Complex, Makurdi          1
# AAUA Sports Complex, Akungba         1
# OAU Sports Complex                   1
# YabaTech Sports Center, Lagos        1
# Name: Venue, dtype: int64

# %%
#for uniformity rename the homeground of OAU Giants as OAU Sports Complex, Ile-Ife
giants_copy['Venue'] = giants_copy['Venue'].replace(['Mainbowl, Oau Sports Complex', 'OAU, Ile-Ife', 'OAU Sports Complex'], 'OAU Sports Complex, Ile-Ife')

# %%
giants_copy = giants_copy.drop(columns=['Time', 'Grouping', 'Format', 'HalfLength'])
giants_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69 entries, 1 to 74
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            69 non-null     object
#  1   Venue           69 non-null     object
#  2   MatchID         69 non-null     object
#  3   Competition     69 non-null     object
#  4   Tie             67 non-null     object
#  5   TieDescr        69 non-null     object
#  6   HomeTeam        69 non-null     object
#  7   AwayTeam        69 non-null     object
#  8   HTHG            69 non-null     object
#  9   HTAG            69 non-null     object
#  10  FTHG            69 non-null     object
#  11  FTAG            69 non-null     object
#  12  PENHG           69 non-null     object
#  13  PENAG           69 non-null     object
#  14  FORM            69 non-null     object
#  15  MatchRemarks    69 non-null     object
#  16  Note            20 non-null     object
# ...

# %%
giants_copy
# Out:
#         Date                             Venue MatchID  \
# 1   20030000                      Futo, Owerri  773855
# 2   20030000                      Futo, Owerri  952508
# 3   20030000                         Buk, Kano  693075
# 4   20030000                         Buk, Kano  657312
# 5   20030000                     Unilag, Lagos  387287
# 6   20030000                     Unilag, Lagos  516262
# 7   20040000                             Benin  563037
# 8   20040000                             Benin  793575
# 10  20050000  Igbinedion University Okada town  366438
# 11  20050000  Igbinedion University Okada town  700535
# 12  20050000  Igbinedion University Okada town  540983
# 13  20050000  Igbinedion University Okada town  560271
# 14  20050000  Igbinedion University Okada town  554226
# 15  20061200                     Ilorin, Kwara  570102
# 17  20070200                         Maiduguri  918704
# 18  20070200                         Maiduguri  681225
# ...

# %% [markdown]
# **Reorder columns in pandas:**
# https://datagy.io/reorder-pandas-columns/

# %%
def reorder_columns(dataframe, col_name, new_position):
    """Reorder a dataframe's column.

    Args:
        dataframe (pd.DataFrame): dataframe to use
        col_name (string): column name to move
        position (0-indexed position): where to relocate column to

    Returns:
        pd.DataFrame: re-assigned dataframe
    """
    temp_col = dataframe[col_name]
    dataframe = dataframe.drop(columns=[col_name])
    dataframe.insert(loc=new_position, column=col_name, value=temp_col)

    return dataframe

# %%
# reordering columns 
giants_copy = reorder_columns(dataframe=giants_copy, col_name='Time24h', new_position=1)
giants_copy = reorder_columns(dataframe=giants_copy, col_name='Venue', new_position=2)
giants_copy = reorder_columns(dataframe=giants_copy, col_name='CompGroup', new_position=3)
giants_copy = reorder_columns(dataframe=giants_copy, col_name='CompID', new_position=4)
giants_copy = reorder_columns(dataframe=giants_copy, col_name='MatchID', new_position=8)
giants_copy = reorder_columns(dataframe=giants_copy, col_name='FORM', new_position=15)
giants_copy = reorder_columns(dataframe=giants_copy, col_name='FormPen', new_position=18)

giants_copy.head(1)
# Out:
#        Date Time24h         Venue    CompGroup CompID Competition      Tie  \
# 1  20030000     NaN  Futo, Owerri  NUFOL Games  29539   2nd NUFOL  Prelims
#
#   TieDescr MatchID    HomeTeam AwayTeam HTHG HTAG FTHG FTAG FORM PENHG PENAG  \
# 1      MD1  773855  OAU Giants  LAUTECH    1    0    1    0    W     0     0
#
#   FormPen MatchRemarks                                               Note  \
# 1     NaN     Approved  Ex-Super Eagles player, Seyi Olofinjana, playe...
#
#   GScorers(Info) MOTM
# 1            NaN  NaN

# %% [markdown]
# **Rename Column:**
# https://www.statology.org/pandas-rename-columns/

# %%
giants_copy = giants_copy.rename(columns={'FORM': 'FTR', 'Time24h': 'Time', 'FormPen': 'PSHTR'})
giants_copy.head(1)
# Out:
#        Date Time         Venue    CompGroup CompID Competition      Tie  \
# 1  20030000  NaN  Futo, Owerri  NUFOL Games  29539   2nd NUFOL  Prelims
#
#   TieDescr MatchID    HomeTeam AwayTeam HTHG HTAG FTHG FTAG FTR PENHG PENAG  \
# 1      MD1  773855  OAU Giants  LAUTECH    1    0    1    0   W     0     0
#
#   PSHTR MatchRemarks                                               Note  \
# 1   NaN     Approved  Ex-Super Eagles player, Seyi Olofinjana, playe...
#
#   GScorers(Info) MOTM
# 1            NaN  NaN

# %% [markdown]
# # CORRECT FORM AND PEN FORM
# Programmatically inspect the Win(W), Draw(D) or Loss(L) for:
# - regular match time result **(FTR)** and
# - penalty shoot-out! **(PSHTR)**

# %%
#Regular time results
conditions = [
    #When OAU Giants are the HomeTeam
    (giants_copy['FTHG'] < giants_copy['FTAG']) & (giants_copy['HomeTeam']=='OAU Giants'),
    (giants_copy['FTHG'] == giants_copy['FTAG']) & (giants_copy['HomeTeam']=='OAU Giants'),
    (giants_copy['FTHG'] > giants_copy['FTAG']) & (giants_copy['HomeTeam']=='OAU Giants'),
    
    #When OAU Giants are the AwayTeam
    (giants_copy['FTHG'] > giants_copy['FTAG']) & (giants_copy['AwayTeam']=='OAU Giants'),
    (giants_copy['FTHG'] == giants_copy['FTAG']) & (giants_copy['AwayTeam']=='OAU Giants'),
    (giants_copy['FTHG'] < giants_copy['FTAG']) & (giants_copy['AwayTeam']=='OAU Giants'),
    ]

values = ['L', 'D', 'W', 'L', 'D', 'W']

giants_copy['FTR'] = np.select(conditions, values)
giants_copy.head(10)
# Out:
#         Date Time                             Venue    CompGroup CompID  \
# 1   20030000  NaN                      Futo, Owerri  NUFOL Games  29539
# 2   20030000  NaN                      Futo, Owerri  NUFOL Games  29539
# 3   20030000  NaN                         Buk, Kano  NUFOL Games  29539
# 4   20030000  NaN                         Buk, Kano  NUFOL Games  29539
# 5   20030000  NaN                     Unilag, Lagos  NUFOL Games  29539
# 6   20030000  NaN                     Unilag, Lagos  NUFOL Games  29539
# 7   20040000  NaN                             Benin  NUFOL Games  29539
# 8   20040000  NaN                             Benin  NUFOL Games  29539
# 10  20050000  NaN  Igbinedion University Okada town  NUFOL Games  29539
# 11  20050000  NaN  Igbinedion University Okada town  NUFOL Games  29539
#
#    Competition        Tie TieDescr MatchID    HomeTeam  AwayTeam HTHG HTAG  \
# 1    2nd NUFOL    Prelims      MD1  773855  OAU Giants   LAUTECH    1    0
# ...

# %%
#Penalty shoot-out results
conditions = [
    #When OAU Giants are the HomeTeam
    (giants_copy['PENHG'] < giants_copy['PENAG']) & (giants_copy['HomeTeam']=='OAU Giants'),
    (giants_copy['PENHG'] > giants_copy['PENAG']) & (giants_copy['HomeTeam']=='OAU Giants'),
        
    #When OAU Giants are the AwayTeam
    (giants_copy['PENHG'] < giants_copy['PENAG']) & (giants_copy['AwayTeam']=='OAU Giants'),
    (giants_copy['PENHG'] > giants_copy['PENAG']) & (giants_copy['AwayTeam']=='OAU Giants'),
    ]

values = ['L', 'W', 'W', 'L']

giants_copy['PSHTR'] = np.select(conditions, values, np.nan)
giants_copy.head(10)
# Out:
#         Date Time                             Venue    CompGroup CompID  \
# 1   20030000  NaN                      Futo, Owerri  NUFOL Games  29539
# 2   20030000  NaN                      Futo, Owerri  NUFOL Games  29539
# 3   20030000  NaN                         Buk, Kano  NUFOL Games  29539
# 4   20030000  NaN                         Buk, Kano  NUFOL Games  29539
# 5   20030000  NaN                     Unilag, Lagos  NUFOL Games  29539
# 6   20030000  NaN                     Unilag, Lagos  NUFOL Games  29539
# 7   20040000  NaN                             Benin  NUFOL Games  29539
# 8   20040000  NaN                             Benin  NUFOL Games  29539
# 10  20050000  NaN  Igbinedion University Okada town  NUFOL Games  29539
# 11  20050000  NaN  Igbinedion University Okada town  NUFOL Games  29539
#
#    Competition        Tie TieDescr MatchID    HomeTeam  AwayTeam HTHG HTAG  \
# 1    2nd NUFOL    Prelims      MD1  773855  OAU Giants   LAUTECH    1    0
# ...

# %% [markdown]
# Creating an **HTR** column for Halftime Results to denote where the team was losing, winning or playing a draw at halftime!

# %%
conditions = [
    #When OAU Giants are the HomeTeam
    (giants_copy['HTHG'] < giants_copy['HTAG']) & (giants_copy['HomeTeam']=='OAU Giants'),
    (giants_copy['HTHG'] == giants_copy['HTAG']) & (giants_copy['HomeTeam']=='OAU Giants'),
    (giants_copy['HTHG'] > giants_copy['HTAG']) & (giants_copy['HomeTeam']=='OAU Giants'),
    
    #When OAU Giants are the AwayTeam
    (giants_copy['HTHG'] > giants_copy['HTAG']) & (giants_copy['AwayTeam']=='OAU Giants'),
    (giants_copy['HTHG'] == giants_copy['HTAG']) & (giants_copy['AwayTeam']=='OAU Giants'),
    (giants_copy['HTHG'] < giants_copy['HTAG']) & (giants_copy['AwayTeam']=='OAU Giants'),
    ]

values = ['L', 'D', 'W', 'L', 'D', 'W']

giants_copy['HTR'] = np.select(conditions, values)
giants_copy.head(10)
# Out:
#         Date Time                             Venue    CompGroup CompID  \
# 1   20030000  NaN                      Futo, Owerri  NUFOL Games  29539
# 2   20030000  NaN                      Futo, Owerri  NUFOL Games  29539
# 3   20030000  NaN                         Buk, Kano  NUFOL Games  29539
# 4   20030000  NaN                         Buk, Kano  NUFOL Games  29539
# 5   20030000  NaN                     Unilag, Lagos  NUFOL Games  29539
# 6   20030000  NaN                     Unilag, Lagos  NUFOL Games  29539
# 7   20040000  NaN                             Benin  NUFOL Games  29539
# 8   20040000  NaN                             Benin  NUFOL Games  29539
# 10  20050000  NaN  Igbinedion University Okada town  NUFOL Games  29539
# 11  20050000  NaN  Igbinedion University Okada town  NUFOL Games  29539
#
#    Competition        Tie TieDescr MatchID    HomeTeam  AwayTeam HTHG HTAG  \
# 1    2nd NUFOL    Prelims      MD1  773855  OAU Giants   LAUTECH    1    0
# ...

# %%
giants_copy = reorder_columns(dataframe=giants_copy, col_name='HTR', new_position=13)

giants_copy.head(1)
# Out:
#        Date Time         Venue    CompGroup CompID Competition      Tie  \
# 1  20030000  NaN  Futo, Owerri  NUFOL Games  29539   2nd NUFOL  Prelims
#
#   TieDescr MatchID    HomeTeam AwayTeam HTHG HTAG HTR FTHG FTAG FTR PENHG  \
# 1      MD1  773855  OAU Giants  LAUTECH    1    0   W    1    0   W     0
#
#   PENAG PSHTR MatchRemarks                                               Note  \
# 1     0   nan     Approved  Ex-Super Eagles player, Seyi Olofinjana, playe...
#
#   GScorers(Info) MOTM
# 1            NaN  NaN

# %%
giants_copy.sample(20)
# Out:
#         Date   Time                             Venue    CompGroup CompID  \
# 64  20220322  16:00       Unilag Sports Center, Akoka   NUGA Games  29200
# 21  20070200    NaN                         Maiduguri   NUGA Games  29200
# 46  20190409  14:00          Oduduwa College, Ile-Ife    Peace Cup  29175
# 52  20190807  16:00         UI Sports Complex, Ibadan         HiFL  29832
# 38  20180808  16:00         UI Sports Complex, Ibadan         HiFL  29832
# 47  20190415  16:00       Ife Grammar School, Ile-Ife    Peace Cup  29175
# 69  20220622  08:00       Unilag Sports Center, Akoka         HiFL  29832
# 43  20181017  16:00       Uam Sports Complex, Makurdi         HiFL  29832
# 14  20050000    NaN  Igbinedion University Okada town  NUFOL Games  29539
# 45  20190000    NaN          Oduduwa College, Ile-Ife    Peace Cup  29175
# 74  20220625  10:00       Unilag Sports Center, Akoka         HiFL  29832
# 31  20140221  07:00       OAU Sports Complex, Ile-Ife   NUGA Games  29200
# ...

# %%
giants_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69 entries, 1 to 74
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            69 non-null     object
#  1   Time            37 non-null     object
#  2   Venue           69 non-null     object
#  3   CompGroup       69 non-null     object
#  4   CompID          69 non-null     object
#  5   Competition     69 non-null     object
#  6   Tie             67 non-null     object
#  7   TieDescr        69 non-null     object
#  8   MatchID         69 non-null     object
#  9   HomeTeam        69 non-null     object
#  10  AwayTeam        69 non-null     object
#  11  HTHG            69 non-null     object
#  12  HTAG            69 non-null     object
#  13  HTR             69 non-null     object
#  14  FTHG            69 non-null     object
#  15  FTAG            69 non-null     object
#  16  FTR             69 non-null     object
# ...

# %% [markdown]
# **Correcting Datatypes**
#
# Putting all the columns in their proper datatypes

# %%
print(giants_copy.columns.tolist())
# Out:
# ['Date', 'Time', 'Venue', 'CompGroup', 'CompID', 'Competition', 'Tie', 'TieDescr', 'MatchID', 'HomeTeam', 'AwayTeam', 'HTHG', 'HTAG', 'HTR', 'FTHG', 'FTAG', 'FTR', 'PENHG', 'PENAG', 'PSHTR', 'MatchRemarks', 'Note', 'GScorers(Info)', 'MOTM']

# %%
# convert score columns to integers
giants_copy[['HTHG', 'HTAG', 'FTHG', 'FTAG', 'PENHG', 'PENAG']] = giants_copy[['HTHG', 'HTAG', 'FTHG', 'FTAG', 'PENHG', 'PENAG']].astype(int)
# converting competition groups to categorical variable
giants_copy[['CompGroup', 'HTR', 'FTR', 'PSHTR']] = giants_copy[['CompGroup', 'HTR', 'FTR', 'PSHTR']].astype("category")

giants_copy
# Out:
#         Date   Time                             Venue    CompGroup CompID  \
# 1   20030000    NaN                      Futo, Owerri  NUFOL Games  29539
# 2   20030000    NaN                      Futo, Owerri  NUFOL Games  29539
# 3   20030000    NaN                         Buk, Kano  NUFOL Games  29539
# 4   20030000    NaN                         Buk, Kano  NUFOL Games  29539
# 5   20030000    NaN                     Unilag, Lagos  NUFOL Games  29539
# 6   20030000    NaN                     Unilag, Lagos  NUFOL Games  29539
# 7   20040000    NaN                             Benin  NUFOL Games  29539
# 8   20040000    NaN                             Benin  NUFOL Games  29539
# 10  20050000    NaN  Igbinedion University Okada town  NUFOL Games  29539
# 11  20050000    NaN  Igbinedion University Okada town  NUFOL Games  29539
# 12  20050000    NaN  Igbinedion University Okada town  NUFOL Games  29539
# 13  20050000    NaN  Igbinedion University Okada town  NUFOL Games  29539
# ...

# %%
giants_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69 entries, 1 to 74
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            69 non-null     object
#  1   Time            37 non-null     object
#  2   Venue           69 non-null     object
#  3   CompGroup       69 non-null     category
#  4   CompID          69 non-null     object
#  5   Competition     69 non-null     object
#  6   Tie             67 non-null     object
#  7   TieDescr        69 non-null     object
#  8   MatchID         69 non-null     object
#  9   HomeTeam        69 non-null     object
#  10  AwayTeam        69 non-null     object
#  11  HTHG            69 non-null     int32
#  12  HTAG            69 non-null     int32
#  13  HTR             69 non-null     category
#  14  FTHG            69 non-null     int32
#  15  FTAG            69 non-null     int32
#  16  FTR             69 non-null     category
# ...

# %% [markdown]
# Saving the cleaned dataframe to a csv file named "oau-giants"

# %%
oau_giants = giants_copy  
oau_giants

#saving cleaned dataframe to memory
oau_giants.to_csv('oau-giants.csv')
# Out:
#         Date   Time                             Venue    CompGroup CompID  \
# 1   20030000    NaN                      Futo, Owerri  NUFOL Games  29539
# 2   20030000    NaN                      Futo, Owerri  NUFOL Games  29539
# 3   20030000    NaN                         Buk, Kano  NUFOL Games  29539
# 4   20030000    NaN                         Buk, Kano  NUFOL Games  29539
# 5   20030000    NaN                     Unilag, Lagos  NUFOL Games  29539
# 6   20030000    NaN                     Unilag, Lagos  NUFOL Games  29539
# 7   20040000    NaN                             Benin  NUFOL Games  29539
# 8   20040000    NaN                             Benin  NUFOL Games  29539
# 10  20050000    NaN  Igbinedion University Okada town  NUFOL Games  29539
# 11  20050000    NaN  Igbinedion University Okada town  NUFOL Games  29539
# 12  20050000    NaN  Igbinedion University Okada town  NUFOL Games  29539
# 13  20050000    NaN  Igbinedion University Okada town  NUFOL Games  29539
# ...

# %% [markdown]
# ### **INSIGHTS FROM THE DATASET**

# %% [markdown]
# Possible Questons:
# - *Total Tournaments Attended? Games Played? Games Won? Games Lost? Games Drawn?*
# - *Worst/Best Finish Per Tournament?*
# - *Win%*
# - *Home Win%, Away Win% or Neutral Win%*
# - *Games won when leading/drawing/losing at halftime*
# - *Games Per Year? Wins/Draws/Loss Per Year?*
# - *Games Per Competition*
# - *Record On Penalties*

# %% [markdown]
# #### **UNIVERSAL PLOT ELEMENTS**

# %%
# Text Detail
team = 'OAU MFT'
team_alias = 'OAU Giants'
coach = 'Chike Egbunnu Olimene'
data_span = '2003-2022'
author = '@allinewsnigeria'

# Font
b_font =  'Merriweather'
t_font = 'Fira Code'
b_fsize = 14
t_fsize = 16

# Colors for Dark Mode
facecolor = '#242526' #18191A is an alternative choice
ax_color = '#3A3B3C'  
plot_color = '#E0CB8A'
off_white = '#FAF9F6'
alt_color = '#303233'


import highlight_text
h_axs = highlight_text.ax_text 
h_fig = highlight_text.fig_text

# %%
# Reset the index of the DataFrame
oau_giants = oau_giants.reset_index(drop=True)
oau_giants
# Out:
#         Date   Time                             Venue    CompGroup CompID  \
# 0   20030000    NaN                      Futo, Owerri  NUFOL Games  29539
# 1   20030000    NaN                      Futo, Owerri  NUFOL Games  29539
# 2   20030000    NaN                         Buk, Kano  NUFOL Games  29539
# 3   20030000    NaN                         Buk, Kano  NUFOL Games  29539
# 4   20030000    NaN                     Unilag, Lagos  NUFOL Games  29539
# 5   20030000    NaN                     Unilag, Lagos  NUFOL Games  29539
# 6   20040000    NaN                             Benin  NUFOL Games  29539
# 7   20040000    NaN                             Benin  NUFOL Games  29539
# 8   20050000    NaN  Igbinedion University Okada town  NUFOL Games  29539
# 9   20050000    NaN  Igbinedion University Okada town  NUFOL Games  29539
# 10  20050000    NaN  Igbinedion University Okada town  NUFOL Games  29539
# 11  20050000    NaN  Igbinedion University Okada town  NUFOL Games  29539
# ...

# %% [markdown]
# ***Questions:***
# Things to do?
#  1.  Breakdown of Games Played
#  2. Honors Won
#  3. Breakdown of Match Results
#  4. Breakdown of Goals Scored

# %%
oau_giants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            69 non-null     object
#  1   Time            37 non-null     object
#  2   Venue           69 non-null     object
#  3   CompGroup       69 non-null     category
#  4   CompID          69 non-null     object
#  5   Competition     69 non-null     object
#  6   Tie             67 non-null     object
#  7   TieDescr        69 non-null     object
#  8   MatchID         69 non-null     object
#  9   HomeTeam        69 non-null     object
#  10  AwayTeam        69 non-null     object
#  11  HTHG            69 non-null     int32
#  12  HTAG            69 non-null     int32
#  13  HTR             69 non-null     category
#  14  FTHG            69 non-null     int32
#  15  FTAG            69 non-null     int32
#  16  FTR             69 non-null     category
# ...

# %% [markdown]
# #### **ALL TIME STATS**
# - Games Played
# - Match Results
# - Form & Streaks
# - Penalty Shootouts
# - Form Pen & Streaks
# - Goals
# - Honors Won

# %%
# Define a function to extract the first four digits from the Date column 
# this is to enable us get the year alone and put it in a separate column 
import re
def extract_year(date_string):
    match = re.match(r"\d{4}", date_string)
    if match:
        return match.group()
    else:
        return None

# Apply the function to the 'Date' column and create a new column called 'Year'
oau_giants['Year'] = oau_giants['Date'].apply(extract_year)
# put the Year column in front of the Date column
oau_giants = reorder_columns(dataframe=oau_giants, col_name='Year', new_position=0)

# Print the DataFrame
oau_giants.head(3)
# Out:
#    Year      Date Time         Venue    CompGroup CompID Competition      Tie  \
# 0  2003  20030000  NaN  Futo, Owerri  NUFOL Games  29539   2nd NUFOL  Prelims
# 1  2003  20030000  NaN  Futo, Owerri  NUFOL Games  29539   2nd NUFOL  Prelims
# 2  2003  20030000  NaN     Buk, Kano  NUFOL Games  29539   2nd NUFOL  Round 2
#
#   TieDescr MatchID    HomeTeam AwayTeam  HTHG  HTAG HTR  FTHG  FTAG FTR  \
# 0      MD1  773855  OAU Giants  LAUTECH     1     0   W     1     0   W
# 1      MD2  952508  OAU Giants     FUTA     3     1   W     5     2   W
# 2      MD3  693075  OAU Giants      UNN     0     0   D     0     0   D
#
#    PENHG  PENAG PSHTR MatchRemarks  \
# 0      0      0   nan     Approved
# 1      0      0   nan     Approved
# 2      0      0   nan     Approved
#
#                                                 Note GScorers(Info) MOTM
# 0  Ex-Super Eagles player, Seyi Olofinjana, playe...            NaN  NaN
# ...

# %% [markdown]
# ##### **Games Played All-Time**

# %%
oau_giants.MatchRemarks.value_counts()
# Out:
# Approved    67
# Walkover     2
# Name: MatchRemarks, dtype: int64

# %%
print(f"{team} Walkover Matches: \n")
walkover_df = oau_giants[oau_giants['MatchRemarks'] !='Approved']
walkover_df.head(2)
print(f"{team} Completed Matches: \n")
approved_df = oau_giants[oau_giants['MatchRemarks'] !='Walkover']
approved_df.head(3)
# Out:
# OAU MFT Walkover Matches:
#     Year      Date   Time                        Venue   CompGroup CompID  \
# 16  2007  20070200    NaN                    Maiduguri  NUGA Games  29200
# 68  2022  20220625  10:00  Unilag Sports Center, Akoka        HiFL  29832
#
#                                   Competition    Tie TieDescr MatchID  \
# 16             2007 NUGA Games (Unimaid 2007)  Group      MD3  967288
# 68  2022 Higher Institutions' Football League  Group      MD7  619874
#
#       HomeTeam    AwayTeam  HTHG  HTAG HTR  FTHG  FTAG FTR  PENHG  PENAG  \
# 16         AAU  OAU Giants     0     0   D     0     3   W      0      0
# 68  OAU Giants        FUTA     0     0   D     3     0   W      0      0
#
#    PSHTR MatchRemarks                                  Note GScorers(Info)  \
# 16   nan     Walkover  AAU (WO). AAU, Ekpoma didn't show up            NaN
# 68   nan     Walkover        FUTA (WO). Futa didn't show up            NaN
#
#    MOTM
# 16  NaN
# 68  NaN
# ...

# %%
print(f"Total Number of Games played by {team} under {coach} is: "+ str(len(approved_df)))
# Out:
# Total Number of Games played by OAU MFT under Chike Egbunnu Olimene is: 67

# %% [markdown]
# ##### **Match Results All-Time**
# Not counting Walkover Ties
#
# - Full Time Results (FTR)
# - Half Time Results (HTR)
# - Second Half Results (SHR)

# %%
# Customizing plot order from the start
order = ['W', 'D', 'L']

# %%
# Creating columns for Second Half Results
approved_df['SHHG'] = approved_df['FTHG'] - approved_df['HTHG']
approved_df['SHAG'] = approved_df['FTAG'] - approved_df['HTAG']
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20136\2578330064.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_df['SHHG'] = approved_df['FTHG'] - approved_df['HTHG']
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20136\2578330064.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_df['SHAG'] = approved_df['FTAG'] - approved_df['HTAG']

# %%
conditions = [
    #When OAU Giants are the HomeTeam
    (approved_df['SHHG'] < approved_df['SHAG']) & (approved_df['HomeTeam']=='OAU Giants'),
    (approved_df['SHHG'] == approved_df['SHAG']) & (approved_df['HomeTeam']=='OAU Giants'),
    (approved_df['SHHG'] > approved_df['SHAG']) & (approved_df['HomeTeam']=='OAU Giants'),
    
    #When OAU Giants are the AwayTeam
    (approved_df['SHHG'] > approved_df['SHAG']) & (approved_df['AwayTeam']=='OAU Giants'),
    (approved_df['SHHG'] == approved_df['SHAG']) & (approved_df['AwayTeam']=='OAU Giants'),
    (approved_df['SHHG'] < approved_df['SHAG']) & (approved_df['AwayTeam']=='OAU Giants'),
    ]

values = ['L', 'D', 'W', 'L', 'D', 'W']

approved_df['SHR'] = np.select(conditions, values)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20136\3912473576.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_df['SHR'] = np.select(conditions, values)

# %%
# reorder the newly created column
approved_df = reorder_columns(dataframe=approved_df, col_name='SHHG', new_position=15)
approved_df = reorder_columns(dataframe=approved_df, col_name='SHAG', new_position=16)
approved_df = reorder_columns(dataframe=approved_df, col_name='SHR', new_position=17)

# %%
approved_df.head(2)
approved_df.info()
# approved_df.to_csv('giants-cleaned-full.csv')
# Out:
#    Year      Date Time         Venue    CompGroup CompID Competition      Tie  \
# 0  2003  20030000  NaN  Futo, Owerri  NUFOL Games  29539   2nd NUFOL  Prelims
# 1  2003  20030000  NaN  Futo, Owerri  NUFOL Games  29539   2nd NUFOL  Prelims
#
#   TieDescr MatchID    HomeTeam AwayTeam  HTHG  HTAG HTR  SHHG  SHAG SHR  FTHG  \
# 0      MD1  773855  OAU Giants  LAUTECH     1     0   W     0     0   D     1
# 1      MD2  952508  OAU Giants     FUTA     3     1   W     2     1   W     5
#
#    FTAG FTR  PENHG  PENAG PSHTR MatchRemarks  \
# 0     0   W      0      0   nan     Approved
# 1     2   W      0      0   nan     Approved
#
#                                                 Note GScorers(Info) MOTM
# 0  Ex-Super Eagles player, Seyi Olofinjana, playe...            NaN  NaN
# 1                                                NaN            NaN  NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67 entries, 0 to 67
# Data columns (total 28 columns):
# ...

# %% [markdown]
# Extracting only the result-related columns to generate our custom plots
# 1. Plot Three Donut Plots side-by-side showing Wins, Draws & Losses respectively
# 2. Print Win%, Draw% and Loss% in the middle of each Donut Plot

# %%
results_df = approved_df[['Year', 'Venue', 'CompGroup', 'Competition', 
                         'HomeTeam', 'AwayTeam', 'HTHG','HTAG','HTR',
                         'SHHG','SHAG','SHR','FTHG','FTAG','FTR']].copy()
results_df.head(3)
# Out:
#    Year         Venue    CompGroup Competition    HomeTeam AwayTeam  HTHG  \
# 0  2003  Futo, Owerri  NUFOL Games   2nd NUFOL  OAU Giants  LAUTECH     1
# 1  2003  Futo, Owerri  NUFOL Games   2nd NUFOL  OAU Giants     FUTA     3
# 2  2003     Buk, Kano  NUFOL Games   2nd NUFOL  OAU Giants      UNN     0
#
#    HTAG HTR  SHHG  SHAG SHR  FTHG  FTAG FTR
# 0     0   W     0     0   D     1     0   W
# 1     1   W     2     1   W     5     2   W
# 2     0   D     0     0   D     0     0   D

# %%
x = oau_giants.CompGroup.unique()
print(x)

comps = " "
for i in range(len(x)):
    if i != len(x) - 1:
        comps += str(x[i]) + ', '
    else:
        comps += str(x[i]) + '.'
print(comps)
# Out:
# ['NUFOL Games', 'PreNUGA', 'NUGA Games', 'WAUG', 'HiFL', 'Peace Cup']
# Categories (6, object): ['HiFL', 'NUFOL Games', 'NUGA Games', 'Peace Cup', 'PreNUGA', 'WAUG']
#  NUFOL Games, PreNUGA, NUGA Games, WAUG, HiFL, Peace Cup.

# %%
ftr = results_df.FTR.value_counts().loc[order].reset_index()
ftr
# Out:
#   index  FTR
# 0     W   35
# 1     D   20
# 2     L   12

# %%
comps
# Out:
# ' NUFOL Games, PreNUGA, NUGA Games, WAUG, HiFL, Peace Cup.'

# %%
# Data for the donut chart
total_games_played = ftr.FTR.sum()

#  Setting up Figure & Axes
fig, ax = plt.subplots(1,3, figsize=(12, 4), facecolor=facecolor, layout='constrained')

# dictionary to access the contents of ftr
emp = {}
for i in range(len(ftr)):             #Cannot put this block of code in the second for loop because   
    emp[ftr['index'][i]] = ftr.FTR[i] #we need to fill the dctionary first before trying to access it.


for i in range(len(ftr)):
    if order[i] == 'W':
        colors = ['#E0CB8A', ax_color]
        num_wins = str(emp[order[i]])
    if order[i] == 'D':
        colors = [ax_color, '#E0CB8A']
        num_draws = str(emp[order[i]])
    if order[i] == 'L':
        colors = [ax_color, '#E0CB8A']
        num_loss = str(emp[order[i]])
    ax[i].set_yticks([])
    ax[i].set_xticks([])
    ax[i].set_facecolor(ax_color)
    ax[i].spines[['top','bottom','left','right']].set_visible(False)
    # Calculate % of that portion/selection
    pct = (emp[order[i]] / total_games_played) * 100 
    # Create the donut chart
    ax[i].pie([100-emp[order[i]], emp[order[i]]], colors=colors, startangle=90, wedgeprops={'width': 1.5})
    # Highlight the variable of interest in the center
    center_circle = plt.Circle((0, 0), 0.62, color=facecolor)
    ax[i].add_artist(center_circle)
     # Add the corresponding percentage text in the center
    ax[i].text(0, 0, f'{pct: .2f}%', va='center', ha='center', fontsize=18,
                font=t_font, fontweight='bold', color='#FAF9F6')

# Wins% Label
h_axs(ax=ax[0], x=-.16, y=-.15, s='<Win %>', color='#FAF9F6', 
      highlight_textprops=[{'color':'#E0CB8A'}], font=b_font,
      fontsize=b_fsize, fontweight='bold', zorder=2)
# Draws% Label
h_axs(ax=ax[1], x=-.16, y=-.15, s='<Draw %>', color='#FAF9F6',
      highlight_textprops=[{'color':'#E0CB8A'}], font=b_font,
      fontsize=b_fsize, fontweight='bold', zorder=2) 
# Loss% Label
h_axs(ax=ax[2], x=-.16, y=-.15, s='<Loss %>', color='#FAF9F6',
      highlight_textprops=[{'color':'#E0CB8A'}], font=b_font,
      fontsize=b_fsize, fontweight='bold', zorder=2)

# Title Text
title = f"{team} <FT MATCH RESULTS> UNDER {coach.upper()} ({data_span})"
# Set titles for the figure and the subplot respectively
h_fig(x=.14, y=1.18, s=title, color='#FAF9F6', highlight_textprops=[{'color':'#E0CB8A'}],
       font=t_font, fontsize=t_fsize, fontweight='bold', zorder=2)

# FT Results Breakdown
txt = f"<Games Played:> " + str(len(approved_df)) + f" <| Wins:> {num_wins}" + f" <| Draws:> {num_draws}" + f" <| Loss:> {num_loss}"

h_fig(x=.22, y=-.08, s=txt, color='#FAF9F6', highlight_textprops=[{'color':'#E0CB8A'}, 
                                                                   {'color':'#E0CB8A'},
                                                                   {'color':'#E0CB8A'},
                                                                   {'color':'#E0CB8A'}],
       font=t_font, fontsize=t_fsize, fontweight='bold', zorder=2)

# Endnotes
endnote_text = (f"Matches Included: {comps}\n" 
                "(Walkover & Abandoned ties are excluded)")

endnote = fig.text(x=0.51, y= -.38, s=endnote_text, color='#FAF9F6', linespacing= 2,
                   ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

# Name Text
name_text = fig.text(x=0.51, y= -.55, s=author, ha='center', va='center', 
                   font=b_font, color='#E0CB8A', alpha=.3, fontsize=b_fsize, zorder=2)

# Path Effects for texts
import matplotlib.patheffects as path_effects
endnote.set_path_effects([path_effects.Stroke(linewidth=.018, foreground='#FAF9F6'),
                          path_effects.Normal()])
name_text.set_path_effects([path_effects.Stroke(linewidth=.005, foreground='#E0CB8A'), 
                            path_effects.Normal()])

# Figure Paddings         
pad_top = "\n\n"
pad_end = "\n\n"

fig.text(x=0.19, y= 1.20, s=pad_top, color='#FAF9F6', linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

fig.text(x=0.51, y= -.50, s=pad_end, color='#FAF9F6', linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

# Save and display
# plt.savefig(f'{coach}-FTR.png', dpi=1000, bbox_inches = "tight")
plt.show();

# %% [markdown]
# ###### %RESULTS AT HALFTIME

# %%
htr = results_df.HTR.value_counts().loc[order].reset_index()
htr
# Out:
#   index  HTR
# 0     W   26
# 1     D   35
# 2     L    6

# %%
# Data for the donut chart
total_games_played = htr.HTR.sum()

#  Setting up Figure & Axes
fig, ax = plt.subplots(1,3, figsize=(12, 4), facecolor=facecolor, layout='constrained')

# dictionary to access the contents of ftr
emp = {}
for i in range(len(htr)):             #Cannot put this block of code in the second for loop because   
    emp[htr['index'][i]] = htr.HTR[i] #we need to fill the dctionary first before trying to access it.


for i in range(len(htr)):
    if order[i] == 'W':
        colors = [plot_color, ax_color]
        num_wins = str(emp[order[i]])
    if order[i] == 'D':
        colors = [ax_color, plot_color]
        num_draws = str(emp[order[i]])
    if order[i] == 'L':
        colors = [ax_color, plot_color]
        num_loss = str(emp[order[i]])
    ax[i].set_yticks([])
    ax[i].set_xticks([])
    ax[i].set_facecolor(ax_color)
    ax[i].spines[['top','bottom','left','right']].set_visible(False)
    # Calculate % of that portion/selection
    pct = (emp[order[i]] / total_games_played) * 100 
    # Create the donut chart
    ax[i].pie([100-emp[order[i]], emp[order[i]]], colors=colors, startangle=90, wedgeprops={'width': 1.5})
    # Highlight the variable of interest in the center
    center_circle = plt.Circle((0, 0), 0.62, color=facecolor)
    ax[i].add_artist(center_circle)
     # Add the corresponding percentage text in the center
    ax[i].text(0, 0, f'{pct: .2f}%', va='center', ha='center', fontsize=18,
                font=t_font, fontweight='bold', color=off_white)

# Wins% Label
h_axs(ax=ax[0], x=-.16, y=-.15, s='<Win %>', color=off_white, 
      highlight_textprops=[{'color':plot_color}], font=b_font,
      fontsize=b_fsize, fontweight='bold', zorder=2)
# Draws% Label
h_axs(ax=ax[1], x=-.16, y=-.15, s='<Draw %>', color=off_white,
      highlight_textprops=[{'color':plot_color}], font=b_font,
      fontsize=b_fsize, fontweight='bold', zorder=2) 
# Loss% Label
h_axs(ax=ax[2], x=-.16, y=-.15, s='<Loss %>', color=off_white,
      highlight_textprops=[{'color':plot_color}], font=b_font,
      fontsize=b_fsize, fontweight='bold', zorder=2)

# Title Text
title = f"{team} <HT MATCH RESULTS> UNDER {coach.upper()} ({data_span})"
# Set titles for the figure and the subplot respectively
h_fig(x=.14, y=1.18, s=title, color=off_white, highlight_textprops=[{'color':plot_color}],
       font=t_font, fontsize=t_fsize, fontweight='bold', zorder=2)

# FT Results Breakdown
txt = f"<Games Played:> " + str(len(approved_df)) + f" <| Wins:> {num_wins}" + f" <| Draws:> {num_draws}" + f" <| Loss:> {num_loss}"

h_fig(x=.22, y=-.08, s=txt, color=off_white, highlight_textprops=[{'color':plot_color}, 
                                                                   {'color':plot_color},
                                                                   {'color':plot_color},
                                                                   {'color':plot_color}],
       font=t_font, fontsize=t_fsize, fontweight='bold', zorder=2)

# Endnotes
endnote_text = (f"Matches Included: {comps}\n" 
                "(Walkover & Abandoned ties are excluded)")

endnote = fig.text(x=0.51, y= -.38, s=endnote_text, color=off_white, linespacing= 2,
                   ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

# Name Text
name_text = fig.text(x=0.51, y= -.55, s=author, ha='center', va='center', 
                   font=b_font, color=plot_color, alpha=.3, fontsize=b_fsize, zorder=2)

# Path Effects for texts
import matplotlib.patheffects as path_effects
endnote.set_path_effects([path_effects.Stroke(linewidth=.018, foreground=off_white),
                          path_effects.Normal()])
name_text.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=plot_color), 
                            path_effects.Normal()])

# Figure Paddings         
pad_top = "\n\n"
pad_end = "\n\n"

fig.text(x=0.19, y= 1.20, s=pad_top, color=off_white, linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

fig.text(x=0.51, y= -.50, s=pad_end, color=off_white, linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

# Save and display
# plt.savefig(f'{coach}-HTR.png', dpi=1000, bbox_inches = "tight")
plt.show();

# %% [markdown]
# ###### %RESULTS IN SECOND HALF

# %%
shr = results_df.SHR.value_counts().loc[order].reset_index()
shr
# Out:
#   index  SHR
# 0     W   27
# 1     D   29
# 2     L   11

# %%
# Data for the donut chart
total_games_played = shr.SHR.sum()

#  Setting up Figure & Axes
fig, ax = plt.subplots(1,3, figsize=(12, 4), facecolor=facecolor, layout='constrained')

# dictionary to access the contents of ftr
emp = {}
for i in range(len(shr)):             #Cannot put this block of code in the second for loop because   
    emp[shr['index'][i]] = shr.SHR[i] #we need to fill the dctionary first before trying to access it.


for i in range(len(shr)):
    if order[i] == 'W':
        colors = [plot_color, ax_color]
        num_wins = str(emp[order[i]])
    if order[i] == 'D':
        colors = [ax_color, plot_color]
        num_draws = str(emp[order[i]])
    if order[i] == 'L':
        colors = [ax_color, plot_color]
        num_loss = str(emp[order[i]])
    ax[i].set_yticks([])
    ax[i].set_xticks([])
    ax[i].set_facecolor(ax_color)
    ax[i].spines[['top','bottom','left','right']].set_visible(False)
    # Calculate % of that portion/selection
    pct = (emp[order[i]] / total_games_played) * 100 
    # Create the donut chart
    ax[i].pie([100-emp[order[i]], emp[order[i]]], colors=colors, startangle=90, wedgeprops={'width': 1.5})
    # Highlight the variable of interest in the center
    center_circle = plt.Circle((0, 0), 0.62, color=facecolor)
    ax[i].add_artist(center_circle)
     # Add the corresponding percentage text in the center
    ax[i].text(0, 0, f'{pct: .2f}%', va='center', ha='center', fontsize=18,
                font=t_font, fontweight='bold', color=off_white)

# Wins% Label
h_axs(ax=ax[0], x=-.16, y=-.15, s='<Win %>', color=off_white, 
      highlight_textprops=[{'color':plot_color}], font=b_font,
      fontsize=b_fsize, fontweight='bold', zorder=2)
# Draws% Label
h_axs(ax=ax[1], x=-.16, y=-.15, s='<Draw %>', color=off_white,
      highlight_textprops=[{'color':plot_color}], font=b_font,
      fontsize=b_fsize, fontweight='bold', zorder=2) 
# Loss% Label
h_axs(ax=ax[2], x=-.16, y=-.15, s='<Loss %>', color=off_white,
      highlight_textprops=[{'color':plot_color}], font=b_font,
      fontsize=b_fsize, fontweight='bold', zorder=2)

# Title Text
title = f"{team} <SECOND HALF MATCH RESULTS> UNDER {coach.upper()} ({data_span})"
# Set titles for the figure and the subplot respectively
h_fig(x=.09, y=1.18, s=title, color=off_white, highlight_textprops=[{'color':plot_color}],
       font=t_font, fontsize=t_fsize, fontweight='bold', zorder=2)

# FT Results Breakdown
txt = f"<Games Played:> " + str(len(approved_df)) + f" <| Wins:> {num_wins}" + f" <| Draws:> {num_draws}" + f" <| Loss:> {num_loss}"

h_fig(x=.22, y=-.08, s=txt, color=off_white, highlight_textprops=[{'color':plot_color}, 
                                                                   {'color':plot_color},
                                                                   {'color':plot_color},
                                                                   {'color':plot_color}],
       font=t_font, fontsize=t_fsize, fontweight='bold', zorder=2)

# Endnotes
endnote_text = (f"Matches Included: {comps}\n" 
                "(Walkover & Abandoned ties are excluded)")

endnote = fig.text(x=0.51, y= -.38, s=endnote_text, color=off_white, linespacing= 2,
                   ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

# Name Text
name_text = fig.text(x=0.51, y= -.55, s=author, ha='center', va='center', 
                   font=b_font, color=plot_color, alpha=.3, fontsize=b_fsize, zorder=2)

# Path Effects for texts
import matplotlib.patheffects as path_effects
endnote.set_path_effects([path_effects.Stroke(linewidth=.018, foreground=off_white),
                          path_effects.Normal()])
name_text.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=plot_color), 
                            path_effects.Normal()])

# Figure Paddings         
pad_top = "\n\n"
pad_end = "\n\n"

fig.text(x=0.19, y= 1.20, s=pad_top, color=off_white, linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

fig.text(x=0.51, y= -.50, s=pad_end, color=off_white, linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

# Save and display
# plt.savefig(f'{coach}-SHR.png', dpi=1000, bbox_inches = "tight")
plt.show();

# %% [markdown]
# #### **1. Breakdown of Games Played**
#
# - Games played per Year
# - Games played per Tournament
# - Games played per Competition Stage
# - Games played per Venue (Home, Away or Neutral)

# %% [markdown]
# ##### **Games Played Per Year**

# %%
# games per year
print(f"Breakdown of The Games Played By {team} Per Year:")
oau_giants['Year'].value_counts()
# Out:
# Breakdown of The Games Played By OAU MFT Per Year:
# 2022    14
# 2019    13
# 2003     6
# 2007     6
# 2005     5
# 2014     5
# 2018     5
# 2011     3
# 2016     3
# 2004     2
# 2010     2
# 2015     2
# 2021     2
# 2006     1
# Name: Year, dtype: int64

# %%
comps = results_df.CompGroup.value_counts().reset_index()
comps
comp_list = comps['index'].to_list()
print("Comp List :\n", comp_list)
# Out:
#          index  CompGroup
# 0         HiFL         19
# 1   NUGA Games         19
# 2  NUFOL Games         13
# 3      PreNUGA          8
# 4    Peace Cup          6
# 5         WAUG          2
# Comp List :
#  ['HiFL', 'NUGA Games', 'NUFOL Games', 'PreNUGA', 'Peace Cup', 'WAUG']

# %%
# we dont need to remeber these dfs so we can give them random names
y = results_df.groupby('CompGroup').FTR.value_counts().reset_index()
# rename single columns
y = y.rename(columns={'level_1' : 'Outcome'})
y.head(9)
# Out:
#      CompGroup Outcome  FTR
# 0         HiFL       W   10
# 1         HiFL       D    7
# 2         HiFL       L    2
# 3  NUFOL Games       W    9
# 4  NUFOL Games       L    3
# 5  NUFOL Games       D    1
# 6   NUGA Games       W    8
# 7   NUGA Games       D    7
# 8   NUGA Games       L    4

# %%
# setting up plot (grid) axes
nrows = 2
ncols = 3
fig, axs = plt.subplots(nrows, ncols, figsize=(6,4), sharey='row',
                        facecolor=facecolor, layout='constrained')

# Define custom color palettes
colors = {'W': '#E0CB8A', 'D': '#79A19D', 'L': 'grey'} #055A87 #923878 --Alt colors (blue & purple)

for row in range(nrows):
    for col in range(ncols):
        # Access the current subplot using axs[row, col]
        ax = axs[row, col]
        # Axes customization
        ax.set_yticks([])
        ax.set_xticks([])
        ax.set_ylim(0, 15)
        ax.set(title="\n")
        #specfiy axis labels
        ax.set_facecolor('#303233') #'#18191A'
        ax.spines[['top','bottom','left','right']].set_visible(False)
                
idx = 0
idy = 0
for i in range(len(comp_list)): 
    # filter the dataframe for rows where CompGroup = comp_list[i]
    new_df = y[y['CompGroup']==comp_list[i]]
    
    # Check if we should switch to the next row  of subplots
    if idy < ncols:
        # plot on top subplot row
        ax_plot = sns.barplot(ax=axs[idx,idy], data=new_df, x=new_df.Outcome, y=new_df.FTR, order=order,
                    palette=colors, color=plot_color, zorder=2)
        ax_plot.set(xlabel=None,
                    ylabel=None,
                    xticks=([]))
        
        idy +=1
        
    else:
        if idy >= ncols:
            idx +=1
            idy -= ncols
            # plot on bottom subplot row
            ax_plot = sns.barplot(ax=axs[idx,idy], data=new_df, x=new_df.Outcome, y=new_df.FTR, order=order,
                         palette=colors, color=plot_color, zorder=2)
            ax_plot.set(xlabel=None, ylabel=None, xticks=([]))
            
            idy +=1
            
# Name Text
name_text = fig.text(x=0.51, y= -.22, s=author, ha='center', va='center', 
                   font=b_font, color=plot_color, alpha=.3, fontsize=8, zorder=2)
name_text.set_path_effects([path_effects.Stroke(linewidth=.005, foreground='#E0CB8A'), 
                            path_effects.Normal()])

# Figure Paddings         
pad_top = "\n\n"
pad_end = "\n\n"
hspace = " "
vspace = " "

# Pad Top 
fig.text(x=0.19, y= 1.08, s=pad_top, color=off_white, linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)
# Pad Bottom
fig.text(x=0.51, y= -.20, s=pad_end, color=off_white, linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)
# Pad left
fig.text(x=-.12, y= 1.15, s=hspace, color=off_white, linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)
# Pad Right 
fig.text(x=1.12, y= 1.15, s=hspace, color=off_white, linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

# Title Text
title = (f"<WINS>, <DRAWS> AND <LOSSES> BY {team} PER TOURNAMENT UNDER {coach.upper()}\n\n" +
         f"                              ({data_span})")
h_fig(x=-.03, y=1.15, s=title, color=off_white, highlight_textprops=[{'color':'#E0CB8A'},
                                                                     {'color':'#79A19D'},
                                                                     {'color':'grey'}],
       font=t_font, fontsize=10, linespacing=1.75, fontweight='bold', zorder=2)

# dictionary to access the contents of ftr
grp = {}
for i in range(len(comps)):   #Dear self, no try reason this code again, you fit no get am 
    grp[comps['index'][i]] = comps.CompGroup[i] #panelbeating too muchhh for the code
    
# Subplot labels
t_one   = str(comp_list[0]) + " |"# + str(grp[comp_list[0]]) + " Games"
t_two   = "NUGA |"# + str(grp[comp_list[1]]) + " Games"
t_three = "NUFOL |"# + str(grp[comp_list[2]]) + " Games"
b_one   = str(comp_list[3]) + " |"# + str(grp[comp_list[3]]) + " Games"
b_two   = str(comp_list[4]) + " |"# + str(grp[comp_list[4]]) + " Games"
b_three = str(comp_list[5]) + " |"# + str(grp[comp_list[5]]) + " Games"

# idx = 0
top_1 = fig.text(x=0.01, y= 0.93, s=f"{t_one} W10 D7 L2  (19)", color=off_white, fontweight='medium',
                 ha='left', va='center', font=b_font, fontsize=8, zorder=2)
top_2 = fig.text(x=0.34, y= 0.93, s=f"{t_two} W8 D7 L4  (19)", color=off_white, fontweight='medium',
                 ha='left', va='center', font=b_font, fontsize=8, zorder=2)
top_3 = fig.text(x=0.67, y= 0.93, s=f"{t_three} W9 D1 L3  (13)", color=off_white, fontweight='medium',
                 ha='left', va='center', font=b_font, fontsize=8, zorder=2)
# # idx = 1 
bottom_1 = fig.text(x=0.01, y= 0.43, s=f"{b_one} W4 D2 L2  (8)", color=off_white, fontweight='medium',
                 ha='left', va='center', font=b_font, fontsize=8, zorder=2)
bottom_2 = fig.text(x=0.34, y= 0.43, s=f"{b_two} W4 D2 L0  (6)", color=off_white, fontweight='medium',
                 ha='left', va='center', font=b_font, fontsize=8, zorder=2)
bottom_3 = fig.text(x=0.67, y= 0.43, s=f"{b_three} W0 D1 L1  (2)", color=off_white, fontweight='medium',
                 ha='left', va='center', font=b_font, fontsize=8, zorder=2)


top_1.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])
top_2.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])
top_3.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])
bottom_1.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])
bottom_2.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])
bottom_3.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])

# Endnotes
endnote_text = (f"Data arranged in descending order of games played in each tournament.\n" 
                "(Walkover & Abandoned ties are excluded)")
endnote = fig.text(x=0.51, y= -.12, s=endnote_text, color='#FAF9F6', linespacing= 2,
                   ha='center', va='center', font=b_font, fontsize=8, zorder=2)
endnote.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])

# Save and display
# plt.savefig(f'{coach}-WDL.png', dpi=1000, bbox_inches = "tight")
plt.show();

# %%
# we dont need to remeber these dfs so we can give them random names
y_ht = results_df.groupby('CompGroup').HTR.value_counts().reset_index()
# rename single columns
y_ht = y_ht.rename(columns={'level_1' : 'Outcome'})
# view df
y_ht.head()
# Out:
#      CompGroup Outcome  HTR
# 0         HiFL       D   12
# 1         HiFL       W    5
# 2         HiFL       L    2
# 3  NUFOL Games       D    7
# 4  NUFOL Games       W    6

# %%
# setting up plot (grid) axes
nrows = 2
ncols = 3
fig, axs = plt.subplots(nrows, ncols, figsize=(6,4), sharey='row',
                        facecolor=facecolor, layout='constrained')

# Define custom color palettes
colors = {'W': '#E0CB8A', 'D': '#79A19D', 'L': 'grey'} #055A87 #923878 --Alt colors (blue & purple)

for row in range(nrows):
    for col in range(ncols):
        # Access the current subplot using axs[row, col]
        ax = axs[row, col]
        # Axes customization
        ax.set_yticks([])
        ax.set_xticks([])
        ax.set_ylim(0, 15)
        ax.set(title="\n")
        #specfiy axis labels
        ax.set_facecolor('#303233') #'#18191A'
        ax.spines[['top','bottom','left','right']].set_visible(False)
                
idx = 0
idy = 0
for i in range(len(comp_list)): 
    # filter the dataframe for rows where CompGroup = comp_list[i]
    new_df = y_ht[y_ht['CompGroup']==comp_list[i]]
    
    # Check if we should switch to the next row  of subplots
    if idy < ncols:
        # plot on top subplot row
        ax_plot = sns.barplot(ax=axs[idx,idy], data=new_df, x=new_df.Outcome, y=new_df.HTR, order=order,
                    palette=colors, color=plot_color, zorder=2)
        ax_plot.set(xlabel=None,
        ylabel=None,
        xticks=([]))
        
        idy +=1
        
    else:
        if idy >= ncols:
            idx +=1
            idy -= ncols
            # plot on bottom subplot row
            ax_plot = sns.barplot(ax=axs[idx,idy], data=new_df, x=new_df.Outcome, y=new_df.HTR, order=order,
                         palette=colors, color=plot_color, zorder=2)
            ax_plot.set(xlabel=None, ylabel=None, xticks=([]))
            
            idy +=1
            
# Name Text
name_text = fig.text(x=0.51, y= -.22, s=author, ha='center', va='center', 
                   font=b_font, color=plot_color, alpha=.3, fontsize=8, zorder=2)
name_text.set_path_effects([path_effects.Stroke(linewidth=.005, foreground='#E0CB8A'), 
                            path_effects.Normal()])

# Figure Paddings         
pad_top = "\n\n"
pad_end = "\n\n"
hspace = " "
vspace = " "

# Pad Top 
fig.text(x=0.19, y= 1.08, s=pad_top, color=off_white, linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)
# Pad Bottom
fig.text(x=0.51, y= -.20, s=pad_end, color=off_white, linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)
# Pad left
fig.text(x=-.12, y= 1.15, s=hspace, color=off_white, linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)
# Pad Right 
fig.text(x=1.12, y= 1.15, s=hspace, color=off_white, linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

# Title Text
title = (f"HT <WINS>, <DRAWS> AND <LOSSES> BY {team} PER TOURNAMENT UNDER {coach.upper()}\n\n" +
         f"                              ({data_span})")
h_fig(x=-.03, y=1.15, s=title, color=off_white, highlight_textprops=[{'color':'#E0CB8A'},
                                                                     {'color':'#79A19D'},
                                                                     {'color':'grey'}],
       font=t_font, fontsize=10, linespacing=1.75, fontweight='bold', zorder=2)

# dictionary to access the contents of ftr
grp = {}
for i in range(len(comps)):   #Dear self, no try reason this code again, you fit no get am 
    grp[comps['index'][i]] = comps.CompGroup[i] #panelbeating too muchhh for the code
    
# Subplot labels
t_one   = str(comp_list[0]) + " |"# + str(grp[comp_list[0]]) + " Games"
t_two   = "NUGA |"# + str(grp[comp_list[1]]) + " Games"
t_three = "NUFOL |"# + str(grp[comp_list[2]]) + " Games"
b_one   = str(comp_list[3]) + " |"# + str(grp[comp_list[3]]) + " Games"
b_two   = str(comp_list[4]) + " |"# + str(grp[comp_list[4]]) + " Games"
b_three = str(comp_list[5]) + " |"# + str(grp[comp_list[5]]) + " Games"


# # idx = 0
# HiFL
top_1 = fig.text(x=0.01, y= 0.93, s=f"{t_one} W5 D12 L2  (19)", color=off_white, fontweight='medium',
                 ha='left', va='center', font=b_font, fontsize=8, zorder=2)
#  NUGA
top_2 = fig.text(x=0.34, y= 0.93, s=f"{t_two} W8 D8 L3  (19)", color=off_white, fontweight='medium',
                 ha='left', va='center', font=b_font, fontsize=8, zorder=2)
# NUFOL
top_3 = fig.text(x=0.67, y= 0.93, s=f"{t_three} W6 D7 L0  (13)", color=off_white, fontweight='medium',
                 ha='left', va='center', font=b_font, fontsize=8, zorder=2)
# # idx = 1 
# PreNUGA
bottom_1 = fig.text(x=0.01, y= 0.43, s=f"{b_one} W4 D3 L1  (8)", color=off_white, fontweight='medium',
                 ha='left', va='center', font=b_font, fontsize=8, zorder=2)
# Peace Cup
bottom_2 = fig.text(x=0.34, y= 0.43, s=f"{b_two} W3 D3 L0  (6)", color=off_white, fontweight='medium',
                 ha='left', va='center', font=b_font, fontsize=8, zorder=2)
# WAUG
bottom_3 = fig.text(x=0.67, y= 0.43, s=f"{b_three} W0 D2 L0  (2)", color=off_white, fontweight='medium',
                 ha='left', va='center', font=b_font, fontsize=8, zorder=2)


top_1.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])
top_2.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])
top_3.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])
bottom_1.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])
bottom_2.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])
bottom_3.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])

# Endnotes
endnote_text = (f"Data arranged in descending order of games played in each tournament.\n" 
                "(Walkover & Abandoned ties are excluded)")
endnote = fig.text(x=0.51, y= -.12, s=endnote_text, color='#FAF9F6', linespacing= 2,
                   ha='center', va='center', font=b_font, fontsize=8, zorder=2)
endnote.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])

# Save and display
# plt.savefig(f'{coach}-WDL.png', dpi=1000, bbox_inches = "tight")
plt.show();

# %% [markdown]
# ##### **TOURNAMENTS ATTENDED**

# %%
oau_giants.groupby('CompGroup')['Competition'].value_counts()
# Out:
# CompGroup    Competition
# HiFL         2019 Higher Institutions' Football League        7
#              2022 Higher Institutions' Football League        6
#              2018 Higher Institutions' Football League        5
#              2021 Higher Institutions' Football League        2
# NUFOL Games  2nd NUFOL                                        6
#              4th NUFOL                                        5
#              3rd NUFOL                                        2
# NUGA Games   2007 NUGA Games (Unimaid 2007)                   6
#              2022 NUGA Games (Unilag 2022)                    6
#              2014 NUGA Games (Oau 2014)                       5
#              2011 NUGA Games (Uniben 2011)                    3
# Peace Cup    Prof. Adedoyin Peace Cup                         6
# PreNUGA      2016 PreNUGA                                     3
#              2010 PreNUGA                                     2
# ...

# %% [markdown]
# #### HONORS WON IN ALL COMPETITIONS
# - Plot-type : Podium shape with outline
# - Numbers printed on each portion of the Podium

# %%
oau_giants.Tie.value_counts()
oau_giants.TieDescr.value_counts()
# Out:
# Group        22
# SF           13
# Final         7
# QF            6
# R16           6
# Prelims       4
# Zonal         3
# Round 2       2
# Super 4       2
# 3rd Place     1
# Group         1
# Name: Tie, dtype: int64
# MD1          11
# MD2          11
# MD3           9
# MD5           7
# MD4           6
# L1            6
# L2            6
# MD6           5
# Round 1       3
# Round 2       2
# 3rd Place     2
# MD7           1
# Name: TieDescr, dtype: int64

# %%
honors_df = oau_giants[(oau_giants['CompGroup'] != 'PreNUGA') &
               (oau_giants['Tie']=='Final') | (oau_giants['Tie']=='3rd Place') | 
               (oau_giants['TieDescr']=='Final') | (oau_giants['TieDescr']=='3rd Place')]
honors_df.shape
# Out:
# (8, 25)

# %%
#Changing Ties to 3rd Place at rows 39 & 52 respectively
honors_df.at[39, 'Tie'] = '3rd Place'
honors_df.at[52, 'Tie'] = '3rd Place'
#Changing TieDescr to Super 4 at rows 39 & 52 respectively
honors_df.at[39, 'TieDescr'] = 'Super 4'
honors_df.at[52, 'TieDescr'] = 'Super 4'

honors_df
# Out:
#     Year      Date   Time                             Venue    CompGroup  \
# 5   2003  20030000    NaN                     Unilag, Lagos  NUFOL Games
# 12  2005  20050000    NaN  Igbinedion University Okada town  NUFOL Games
# 19  2007  20070200    NaN                         Maiduguri   NUGA Games
# 29  2014  20140222  15:00       OAU Sports Complex, Ile-Ife   NUGA Games
# 39  2018  20181103  11:00              Agege Stadium, Lagos         HiFL
# 45  2019  20190430  16:00       OAU Sports Complex, Ile-Ife    Peace Cup
# 52  2019  20191026  11:00              Agege Stadium, Lagos         HiFL
# 62  2022  20220325  16:00       Unilag Sports Center, Akoka   NUGA Games
#
#    CompID                                Competition        Tie TieDescr  \
# 5   29539                                  2nd NUFOL  3rd Place      MD6
# 12  29539                                  4th NUFOL      Final      MD5
# 19  29200             2007 NUGA Games (Unimaid 2007)      Final      MD6
# ...

# %%
honors_df.PSHTR.value_counts()
# Out:
# nan    5
# L      3
# W      0
# Name: PSHTR, dtype: int64

# %%
# Create empty dictionary
finals_dict = {}
# populating the dictionary
#  Total Num of Finals Played - Main Finals & Third Place
finals_dict['Honors Contested'] = len(honors_df)


# Getting number of games played in Finals & 3rd Place contests
h = honors_df.Tie.value_counts().reset_index()

for i in range(len(h)):
    finals_dict[str(h['index'][i] + ' Played')] = h['Tie'][i]

# Split dfs    
#  Finals
finals_df = honors_df[(honors_df['Tie'] == 'Final')]

res_f = finals_df.FTR.value_counts().loc[order].reset_index()
for i in range(len(res_f)):
    finals_dict['Final ('+ str(res_f['index'][i]) +')'] = res_f['FTR'][i]
    
#  3rd Place Playoffs  
third_place_df = honors_df[(honors_df['Tie'] == '3rd Place')]   

res_3rd = third_place_df.FTR.value_counts().loc[order].reset_index()
for i in range(len(res_3rd)):
    finals_dict['3rd Place ('+ str(res_3rd['index'][i]) +')'] = res_3rd['FTR'][i]
    
#  Print Dictionary
finals_dict
# Out:
# {'Honors Contested': 8,
#  'Final Played': 5,
#  '3rd Place Played': 3,
#  'Final (W)': 2,
#  'Final (D)': 2,
#  'Final (L)': 1,
#  '3rd Place (W)': 1,
#  '3rd Place (D)': 1,
#  '3rd Place (L)': 1}

# %%
psht_order = ['W','L','nan']
f = finals_df.PSHTR.value_counts().loc[psht_order].reset_index()

# populating the dictionary
    #  For PSHTR in Finals
for i in range(len(f)-1): # minus 1 cause we dont want to include nan based on the psht_order
    if i == 0:
        finals_dict['Final PSHT (' + str(f['index'][i] + ')')] = f['PSHTR'][i]
    else:
        finals_dict['Final PSHT (' + str(f['index'][i] + ')')] = f['PSHTR'][i]
        
    #  For PSHTR in Third Place Contests
t = third_place_df.PSHTR.value_counts().loc[psht_order].reset_index()
for i in range(len(t)-1): # minus 1 cause we dont want to include nan based on the psht_order
    if i == 0:
        finals_dict['3rd Place PSHT (' + str(t['index'][i] + ')')] = t['PSHTR'][i]
    else:
        finals_dict['3rd Place PSHT (' + str(t['index'][i] + ')')] = t['PSHTR'][i]

finals_dict
# Out:
# {'Honors Contested': 8,
#  'Final Played': 5,
#  '3rd Place Played': 3,
#  'Final (W)': 2,
#  'Final (D)': 2,
#  'Final (L)': 1,
#  '3rd Place (W)': 1,
#  '3rd Place (D)': 1,
#  '3rd Place (L)': 1,
#  'Final PSHT (W)': 0,
#  'Final PSHT (L)': 2,
#  '3rd Place PSHT (W)': 0,
#  '3rd Place PSHT (L)': 1}

# %%
from matplotlib.patches import Arc, Circle, Rectangle

#  Setting up Figure & Axes
fig, ax = plt.subplots(figsize=(12, 4), facecolor=facecolor)
ax.set(facecolor=facecolor, xticks=([]), yticks=([]))
ax.spines[['top','bottom','left','right']].set_visible(False)

# Creating the Podium 
pod_third = Rectangle((0.2,.5),.2,.1, fc=facecolor, ec='grey')
pod_first = Rectangle((0.4,.5),.2,.2, fc=facecolor, ec='grey')
pod_second = Rectangle((0.6,.5),.2,.1, fc=facecolor, ec='grey')

podium = [pod_third, pod_first, pod_second]
for part in podium:
    ax.add_patch(part)

# Podium Labels
ax.text(x=.3, y= .4, s='Silver', color='grey', ha='center',
            va='center', font=b_font, fontsize=10, zorder=2)
ax.text(x=.5, y= .4, s='Gold', color='grey', ha='center',
            va='center', font=b_font, fontsize=10, zorder=2)
ax.text(x=.7, y= .4, s='Bronze', color='grey', ha='center',
            va='center', font=b_font, fontsize=10, zorder=2)

# Annotations
# Text for count Honors Won
gold_medals = finals_dict['Final (W)'] + finals_dict['Final PSHT (W)']
silver_medals = finals_dict['Final (L)'] + finals_dict['Final PSHT (L)']
bronze_medals = finals_dict['3rd Place (W)'] + finals_dict['3rd Place PSHT (W)']

ax.text(x=.3, y= .7, s=f'{silver_medals}', color=plot_color, ha='center',
            va='center', font=t_font, fontweight='bold', fontsize=18, zorder=2)
ax.text(x=.5, y= .8, s=f'{gold_medals}', color=plot_color, ha='center',
            va='center', font=t_font, fontweight='bold', fontsize=18, zorder=2)
ax.text(x=.7, y= .7, s=f'{bronze_medals}', color=plot_color, ha='center',
            va='center', font=t_font, fontweight='bold', fontsize=18, zorder=2)

# Title Text
custom_space = "                              "
title_text = (f"A PODIUM PLOT OF THE <HONORS WON> BY {team} UNDER {coach.upper()}\n"
                f"\n\n{custom_space} ({data_span})")
h_fig(x=.20, y=1.1, s=title_text, color=off_white, highlight_textprops=[{'color':plot_color}],
       font=t_font, fontsize=13, fontweight='bold', zorder=2)
# title = fig.text(x=0.5, y= 1.1, s=title_text, ha='center', va='center', linespacing=2,
#                    font=t_font, color=off_white, fontsize=12, zorder=2)
# title.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
#                             path_effects.Normal()])

# Total Honor Wons
total_honors = gold_medals + silver_medals + bronze_medals
t_hnr_txt = f'<Total Honors:> {total_honors}'
# h_fig(x=.45, y=.90, s=t_hnr_txt, color='grey', highlight_textprops=[{'color':'grey'}],
#        font=t_font, fontsize=13, fontweight='bold', zorder=2)

# Additional Text
brkdwn_txt = '\n'.join([f'{key} : {value}' for key, value in finals_dict.items()])
# Split the string into four smaller parts
parts = brkdwn_txt.split('\n')

# Join in threes and format as strings
brkdwn_txt_1 = '\n'.join(parts[:3])
brkdwn_txt_2 = '\n'.join(parts[3:6])
brkdwn_txt_3 = '\n'.join(parts[6:9])
brkdwn_txt_4 = '\n'.join(parts[9:])

brkdwn_txt1 = fig.text(x=0.25, y= 0.25, s=f'{brkdwn_txt_1}', color=off_white, linespacing= 2,
                ha='left', va='top', font=b_font, fontsize=10, zorder=2)
brkdwn_txt2 = fig.text(x=0.40, y= 0.25, s=f'{brkdwn_txt_2}', color=off_white, linespacing= 2,
                ha='left', va='top', font=b_font, fontsize=10, zorder=2)
brkdwn_txt3 = fig.text(x=0.50, y= 0.25, s=f'{brkdwn_txt_3}', color=off_white, linespacing= 2,
                ha='left', va='top', font=b_font, fontsize=10, zorder=2)
brkdwn_txt4 = fig.text(x=0.63, y= 0.25, s=f'{brkdwn_txt_4}', color=off_white, linespacing= 2,
                ha='left', va='top', font=b_font, fontsize=10, zorder=2)

brkdwn_txt1.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])
brkdwn_txt2.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])
brkdwn_txt3.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])
brkdwn_txt4.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])


#  Name Text
name_text = fig.text(x=0.52, y= -.10, s=author, ha='center', va='center', 
                   font=b_font, color=plot_color, alpha=.3, fontsize=10, zorder=2)
name_text.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])

# Pad Top 
fig.text(x=0.5, y= 1.13, s=pad_top, color=off_white, linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)
# Pad Bottom
fig.text(x=0.5, y= -.10, s=pad_end, color=off_white, linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

# Save and display
# plt.savefig(f'{coach}-HONORS.png', dpi=1000, bbox_inches = "tight")
plt.show();

# %% [markdown]
# ##### OPPONENTS PLAYED
# - Circle with outline
# - Total Num of different teams won against
# - Regular Customers
# - Our Boyfriends

# %%
results_df.sample(5)
# Out:
#     Year                        Venue   CompGroup  \
# 44  2019     Oduduwa College, Ile-Ife   Peace Cup
# 46  2019  OAU Sports Complex, Ile-Ife        HiFL
# 64  2022  Unilag Sports Center, Akoka        HiFL
# 31  2015                  Unn, Nsukka        WAUG
# 14  2007                    Maiduguri  NUGA Games
#
#                                       Competition    HomeTeam      AwayTeam  \
# 44                       Prof. Adedoyin Peace Cup  OAU Giants  E-Springs FC
# 46      2019 Higher Institutions' Football League  OAU Giants   UI Pioneers
# 64      2022 Higher Institutions' Football League  OAU Giants         ABUAD
# 31  2015 West African University Games (Unn 2015)  OAU Giants           BSU
# 14                 2007 NUGA Games (Unimaid 2007)     UNIMAID    OAU Giants
#
#     HTHG  HTAG HTR  SHHG  SHAG SHR  FTHG  FTAG FTR
# 44     1     0   W     1     0   W     2     0   W
# 46     2     0   W     0     0   D     2     0   W
# ...

# %%
h_teams = results_df.HomeTeam.to_list()
print('Teams from HomeTeam Col:\n', h_teams, '\n\n')
a_teams = results_df.AwayTeam.to_list()
print('Teams from AwayTeam Col:\n', a_teams)
# Out:
# Teams from HomeTeam Col:
#  ['OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'UNIMAID', 'OAU Giants', 'OAU Giants', 'ABU', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'UI Pioneers ', 'OAU Giants', 'OAU Giants', 'UAM Tillers', 'OAU Giants', 'Sabo Strikers', 'Ase Irorun', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'Successful Christian Mission FC', 'OAU Giants', 'UI Pioneers', 'OAU Giants', 'LASU Blazers', 'OAU Giants', 'UAM Tillers', 'OAU Giants', 'AAUA Luminaries', 'OAU Giants', 'AAUA', 'OAU Giants', 'IAUE', 'OAU Giants', 'UI', 'KSU', 'OAU Giants', 'OAU Giants', 'TASUED', 'OAU Giants', 'OAU Giants', 'OAU Giants', 'OAU Giants']
#
#
# Teams from AwayTeam Col:
# ...

# %% [markdown]
# You could get the teams by saying len of list divided by 2 or calculating len(df)-1 *minus accounts for 'OAU Giants' who will be sitting in one of the rows*
#
# The problem here is the names aren't unique! Unilorin & Unilorin Warriors (same for AAUA & AAUA Luminaries) are regarded as different teams whereas, they are the same team with different identities (based on competition participation) On inspection, some teams have whitespaces before or after thir names and that causes them to be regarded as another team (whereas it only inflates the dataset). We need to apply a regex to remove all trailing and leading whitespaces in the column carrying the team names

# %%
results_df.HomeTeam.value_counts().reset_index()
# Out:
#                               index  HomeTeam
# 0                        OAU Giants        51
# 1                       UAM Tillers         2
# 2                           UNIMAID         1
# 3                               ABU         1
# 4                      UI Pioneers          1
# 5                     Sabo Strikers         1
# 6                        Ase Irorun         1
# 7   Successful Christian Mission FC         1
# 8                       UI Pioneers         1
# 9                      LASU Blazers         1
# 10                  AAUA Luminaries         1
# 11                             AAUA         1
# 12                             IAUE         1
# 13                               UI         1
# 14                              KSU         1
# 15                           TASUED         1

# %%
results_df.AwayTeam.value_counts().reset_index()
# Out:
#                 index  AwayTeam
# 0          OAU Giants        16
# 1             LAUTECH         3
# 2              UNILAG         3
# 3                EKSU         3
# 4                 UNN         3
# 5                 ABU         2
# 6         UI Pioneers         2
# 7              UNICAL         2
# 8                FUTA         2
# 9             UNIMAID         2
# 10        UAM Tillers         2
# 11  UNILORIN Warriors         2
# 12           UNILORIN         2
# 13  Kings Dominion FC         1
# 14       E-Springs FC         1
# 15     Akoraye Eagles         1
# 16       LASU Blazers         1
# 17    AAUA Luminaries         1
# 18              FUDMA         1
# 19            UNILAG          1
# 20              ABUAD         1
# 21               AAUA         1
# 22                NDU         1
# 23                BSU         1
# 24               FUTO         1
# 25                KSU         1
# 26                 UI         1
# 27          ACHIEVERS         1
# ...

# %%
# Remove leading and trailing whitespaces from 'HomeTeam' column
results_df['HomeTeam'] = results_df.HomeTeam.str.strip()
results_df.HomeTeam.value_counts()
# Out:
# OAU Giants                         51
# UI Pioneers                         2
# UAM Tillers                         2
# UNIMAID                             1
# ABU                                 1
# Sabo Strikers                       1
# Ase Irorun                          1
# Successful Christian Mission FC     1
# LASU Blazers                        1
# AAUA Luminaries                     1
# AAUA                                1
# IAUE                                1
# UI                                  1
# KSU                                 1
# TASUED                              1
# Name: HomeTeam, dtype: int64

# %%
# Remove leading and trailing whitespaces from 'AwayTeam' column
results_df['AwayTeam'] = results_df.AwayTeam.str.strip()
results_df.AwayTeam.value_counts()
# Out:
# OAU Giants           16
# UNILAG                4
# LAUTECH               3
# UNN                   3
# EKSU                  3
# UNILORIN              3
# UNICAL                2
# FUTA                  2
# UAM Tillers           2
# UNILORIN Warriors     2
# UI Pioneers           2
# UNIMAID               2
# ABU                   2
# AAUA                  1
# Akoraye Eagles        1
# Kings Dominion FC     1
# LASU Blazers          1
# AAUA Luminaries       1
# FUDMA                 1
# ABUAD                 1
# E-Springs FC          1
# KSU                   1
# BSU                   1
# NDU                   1
# UI                    1
# ACHIEVERS             1
# UNIUYO                1
# FUT-YOLA              1
# OOU                   1
# BUK                   1
# FUT MUBI              1
# UNIPORT               1
# FUTO                  1
# UNIOSUN               1
# Name: AwayTeam, dtype: int64

# %%
# Define a dictionary to map the items to the common name
replacement_dict = {'UAM Tillers' : 'UAM'  ,      
                    'UNILORIN Warriors' : 'UNILORIN',   
                    'UI Pioneers' : 'UI',
                    'LASU Blazers' : 'LASU'  ,       
                    'AAUA Luminaries' : 'AAUA'
                    }
    
# Replace the items in 'AwayTeam' Column with the common name using replace
results_df['AwayTeam'] = results_df['AwayTeam'].replace(replacement_dict)
# Replace the items in 'HomeTeam' Column with the common name using replace
results_df['HomeTeam'] = results_df['HomeTeam'].replace(replacement_dict)

# %%
results_df.AwayTeam.value_counts()
# Out:
# OAU Giants           16
# UNILORIN              5
# UNILAG                4
# LAUTECH               3
# UNN                   3
# EKSU                  3
# UI                    3
# AAUA                  2
# FUTA                  2
# UAM                   2
# UNICAL                2
# UNIMAID               2
# ABU                   2
# BSU                   1
# Kings Dominion FC     1
# E-Springs FC          1
# LASU                  1
# FUDMA                 1
# ABUAD                 1
# Akoraye Eagles        1
# ACHIEVERS             1
# NDU                   1
# KSU                   1
# UNIUYO                1
# FUT-YOLA              1
# OOU                   1
# BUK                   1
# FUT MUBI              1
# UNIPORT               1
# FUTO                  1
# UNIOSUN               1
# Name: AwayTeam, dtype: int64

# %%
results_df.HomeTeam.value_counts()
# Out:
# OAU Giants                         51
# UI                                  3
# UAM                                 2
# AAUA                                2
# UNIMAID                             1
# ABU                                 1
# Sabo Strikers                       1
# Ase Irorun                          1
# Successful Christian Mission FC     1
# LASU                                1
# IAUE                                1
# KSU                                 1
# TASUED                              1
# Name: HomeTeam, dtype: int64

# %%
teams_list = results_df.HomeTeam.to_list() + results_df.AwayTeam.to_list()

# Teams in the Dataset
teams = set(teams_list)
teams
# Out:
# {'AAUA',
#  'ABU',
#  'ABUAD',
#  'ACHIEVERS',
#  'Akoraye Eagles',
#  'Ase Irorun',
#  'BSU',
#  'BUK',
#  'E-Springs FC',
#  'EKSU',
#  'FUDMA',
#  'FUT MUBI',
#  'FUT-YOLA',
#  'FUTA',
#  'FUTO',
#  'IAUE',
#  'KSU',
#  'Kings Dominion FC',
#  'LASU',
#  'LAUTECH',
#  'NDU',
#  'OAU Giants',
#  'OOU',
#  'Sabo Strikers',
#  'Successful Christian Mission FC',
#  'TASUED',
#  'UAM',
#  'UI',
#  'UNICAL',
#  'UNILAG',
#  'UNILORIN',
#  'UNIMAID',
#  'UNIOSUN',
#  'UNIPORT',
#  'UNIUYO',
#  'UNN'}

# %%
# Total Num of Teams Faced
opp_faced = len(teams) - 1
opp_faced
# Out:
# 35

# %%
# Filter the list to only include items that occur more than once
opp_freq = [team for team in teams_list if (teams_list.count(team) > 2) & (team != 'OAU Giants')]
print(opp_freq, '\n')

teams_face_more_than1 = set(opp_freq)
print(teams_face_more_than1)
# Out:
# ['UNIMAID', 'ABU', 'UI', 'UAM', 'UI', 'UAM', 'AAUA', 'AAUA', 'UI', 'LAUTECH', 'UNN', 'ABU', 'UNILAG', 'LAUTECH', 'ABU', 'UNIMAID', 'LAUTECH', 'UNIMAID', 'UNILORIN', 'UNN', 'UI', 'EKSU', 'UNILAG', 'UNN', 'UNILORIN', 'AAUA', 'EKSU', 'UI', 'UAM', 'UNILORIN', 'UI', 'UAM', 'UNILORIN', 'AAUA', 'UNILAG', 'UNILORIN', 'EKSU', 'UNILAG']
#
# {'UNIMAID', 'ABU', 'LAUTECH', 'UI', 'UNILAG', 'UNN', 'AAUA', 'UAM', 'UNILORIN', 'EKSU'}

# %% [markdown]
# ###### A COOL FUNCTION USER CAN USE TO MAKE THE STREAMLIT APP INTERACTIVE. THE USER NEED ONLY SELECT A TEAM FROM A DROPDOWN TO SEE THE RECORD AGAINST THEM

# %%
# Funtion to return WX DX LX for any teamm in osu-giants df
def get_record (opponent, FTR=True, HTR=False, SHR=False):
    temp_df = results_df[(results_df.HomeTeam == opponent) | (results_df.AwayTeam == opponent)]
    total_meetings = len(temp_df)
    
#     if FTR != False: ---trying to develop it into a robust function but maybe later.
    order = ['W','D','L']
    outcomes_vs_team = temp_df.FTR.value_counts().loc[order].reset_index()
    
    record_dict = {}
    for i in range(len(outcomes_vs_team)):
        record_dict[outcomes_vs_team['index'][i]] = outcomes_vs_team.FTR[i]
    # Format response String    
    record_vs_team = f"W{record_dict['W']} D{record_dict['W']} L{record_dict['L']}"
#     else:
#         raise TaskError = "I should do nothing?"
    
    return total_meetings, record_vs_team

# %% [markdown]
# ###### TOP 10 MOST FACED OPPONENTS (MIN OF 3 GAMES)

# %%
# Setting up the Figure
fig, ax = plt.subplots(1,1, figsize=(12,8), facecolor=facecolor)

# Axes customization
ax.set_yticks([])
ax.set_xticks([])
ax.set_xlim(-4, 12)

#specfiy axis labels
ax.set_facecolor(facecolor) #'#18191A' '#303233'
ax.spines[['top','bottom','left','right']].set_visible(False)


# Calculating the number of meetings with each team in the list
unique_items, item_counts = np.unique(opp_freq, return_counts=True)

# Sort Teams descending order of meetings
sorted_indices = np.argsort(item_counts)[::-1]
unique_items = unique_items[sorted_indices]
item_counts = item_counts[sorted_indices]

# Adding Plot
sns.countplot(ax=ax, y=opp_freq, order=unique_items, 
              facecolor="none", edgecolor=plot_color, linewidth=.5);

title_text = (f"TOP 10 <MOST FACED TEAMS> IN ALL COMPS BY {coach.upper()} WITH {team}\n"
              f"\n\n{custom_space} ({data_span})")
h_fig(x=0.13, y=1.03, s=title_text, color=off_white, highlight_textprops=[{'color':plot_color}],
       font=t_font, fontsize=15, fontweight='bold', zorder=2)
# title = fig.text(x=0.52, y= .99, s=title_text, ha='center', va='center', linespacing=2.2,
#                    font=t_font, color=off_white, fontsize=15, zorder=2)
# title.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
#                             path_effects.Normal()])



#  Name Text
# name_text = fig.text(x=0.52, y= -.01, s=author, ha='center', va='center', 
#                    font=b_font, color=plot_color, alpha=.3, fontsize=14, zorder=2)
# name_text.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
#                             path_effects.Normal()])
#  Alt Name Text
name_text = ax.text(x=9.0, y= 8.8, s=author, ha='center', va='center', 
                   font=b_font, color=plot_color, alpha=.3, fontsize=13, zorder=2)
name_text.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])

#  FIGURE PADDING
# Pad Top 
fig.text(x=0.5, y= 1.01, s=pad_top, color=off_white, linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)
# Pad Bottom
fig.text(x=0.5, y= 0.2, s=pad_end, color=off_white, linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)
## Pad left
# fig.text(x=-.12, y= 1.15, s=hspace, color=off_white, linespacing= 2,
#                 ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)
# Pad Right 
fig.text(x=0.97, y=0, s=hspace, color=off_white, linespacing= 2,
                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

# ANNOTATIONS
# The Teams to be labelled on the left of the Spines
tten_opp = list(unique_items)
 
txt_offset = .4 # Distance of the text from the height of the bar
x_origin = 0
vspacing = 0

for i in range(len(tten_opp)):
    label = ax.text(x=-.5, y= vspacing, s=f'{tten_opp[i]}', ha='right', va='center', fontweight='medium',
                   font=b_font, color=plot_color, fontsize=12, zorder=2)
    label.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=plot_color), 
                            path_effects.Normal()])
    # Text to the rightmost part of the plot
    bar_height = opp_freq.count(tten_opp[i])
    num_of_meetings = bar_height # Since the plot was made by how many times they faced each other
    hspacing = x_origin + bar_height + txt_offset
    meetings = ax.text(x=hspacing, y=vspacing, s=f'{num_of_meetings}', ha='left', va='center',
                       fontweight='medium', font=b_font, color=off_white, fontsize=12, zorder=2)
    meetings.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])
    
    vspacing +=1


    
# Create custom left spine   
custom_lspine = plt.Rectangle((0,-1), 0, 12, edgecolor=plot_color, linewidth=.8)
opp_count_circle = plt.Circle((9,6), .7, edgecolor=plot_color, facecolor=facecolor, linewidth=.8)

Patches = [custom_lspine, opp_count_circle]
for patch in Patches:
    ax.add_patch(patch)

# In-Circle Text
crc_text = ax.text(x=9, y=6.0, s=opp_faced, ha='center', va='center', fontweight='bold',
                   font=t_font, color=plot_color, fontsize=18, zorder=2)
crc_text.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])

# Circle label 
circle_label_txt = "Total Number of Teams Faced\n(Walkover & Abandoned ties are excluded)"
crc_lbl = ax.text(x=9, y=7.5, s=circle_label_txt, ha='center', va='center', fontweight='medium',
                   font=b_font, color=off_white, fontsize=12, zorder=2) 
crc_lbl.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=off_white), 
                            path_effects.Normal()])

# # Save and display
# plt.savefig(f'{coach}-TOPTEN.png', dpi=1000, bbox_inches = "tight")
plt.show();

# %% [markdown]
# ##### Dashboard of FT Results based on HT Results
# Games Won, Drawn or Lost while Leading/Losing at HT

# %% [markdown]
# ##### GOALS RECORD
# - Goals Scored
# - Goals Conceeded
#
# - Goals Scored in Wins vs Goal Scored in games that weren't Won

# %% [markdown]
# #### FORM ANALYSIS
#
# -  FORM AGAINST OTHER TEAMS (USER ADJUSTABLE APP)
# -  FORM IN GAMES (HT SHR & FT)

# %% [markdown]
# FORM APP (VS OPPONENTS)

# %%
team = 'OAU'
opponent = 'UNILORIN'
total_meetings , record_vs_opp = get_record(opponent)
print(f'In {total_meetings} meetings against {opponent}, Team {team} has the record: {record_vs_opp}')
# Out:
# In 5 meetings against UNILORIN, Team OAU has the record: W2 D2 L1

# %%
comps
# Out:
#          index  CompGroup
# 0         HiFL         19
# 1   NUGA Games         19
# 2  NUFOL Games         13
# 3      PreNUGA          8
# 4    Peace Cup          6
# 5         WAUG          2

# %% [markdown]
# ###### STREAMLIT APP

# %%
# def Record_App (select_opponent):
# #     import matplotlib.pyplot as plt
# #     import highlight_text
# #     h_axs = highlight_text.ax_text 
# #     h_fig = highlight_text.fig_text
# #     # plot_colors --- Uncomment to use/change code(if needed)
# #     facecolor = '#242526' #18191A is an alternative choice
# #     ax_color = '#3A3B3C'  
# #     plot_color = '#E0CB8A'
# #     off_white = '#FAF9F6'
# #     alt_color = '#303233'
    
# #     # fonting
# #     t_font = 'Fira Code'
# #     t_fsize = 16
# #     b_font = 'Merriweather'
# #     b_fsize = 14

# #     # Annotations & Texts
# #     author ='@allinewsnigeria'

#     # Function to return WX DX LX for any teamm in osu-giants df
#     def get_record (opponent, FTR=True, HTR=False, SHR=False):
#         temp_df = results_df[(results_df.HomeTeam == opponent) | (results_df.AwayTeam == opponent)]
#         total_meetings = len(temp_df)
#         order = ['W','D','L']
#         outcomes_vs_team = temp_df.FTR.value_counts().loc[order].reset_index()
#         record_dict = {}
#         for i in range(len(outcomes_vs_team)):
#             record_dict[outcomes_vs_team['index'][i]] = outcomes_vs_team.FTR[i]
#         # Format response String    
#         record_vs_team = f"W{record_dict['W']} D{record_dict['W']} L{record_dict['L']}"
#         return total_meetings, record_vs_team, temp_df

#     # input variables
#     team = 'OAU'
#     total_meetings , record_vs_opp , plot_df = get_record((str(select_opponent))
                                                          
#     # Display Message
#     display_msg = (f"In {total_meetings} meetings against {opponent},"
#                    f" Team {team} has this record: {record_vs_opp}")
    
#     ## PLOT TO RETURN FOR THE RECORD AGAINST THE OPPONENT
#     # Order of Results
#     order = ['W', 'D', 'L']
    
#     # Data for the donut chart
#     total_meetings = plot_df.FTR.sum()

#     #  Setting up Figure & Axes
#     fig, ax = plt.subplots(1,3, figsize=(12, 4), facecolor=facecolor, layout='constrained')

#     # dictionary to access the contents of ftr
#     emp = {}
#     for i in range(len(plot_df)):             #Cannot put this block of code in the second for loop because   
#         emp[plot_df['index'][i]] = plot_df.FTR[i] #we need to fill the dctionary first before trying to access it.


#     for i in range(len(plot_df)):
#         if order[i] == 'W':
#             colors = [plot_color, ax_color]off_white
#             num_wins = str(emp[order[i]])
#         if order[i] == 'D':
#             colors = [ax_color, plot_color]
#             num_draws = str(emp[order[i]])
#         if order[i] == 'L':
#             colors = [ax_color,plot_color]
#             num_loss = str(emp[order[i]])
#         ax[i].set_yticks([])
#         ax[i].set_xticks([])
#         ax[i].set_facecolor(ax_color)
#         ax[i].spines[['top','bottom','left','right']].set_visible(False)
#         # Calculate % of that portion/selection
#         pct = (emp[order[i]] / total_meetings) * 100 
#         # Create the donut chart
#         ax[i].pie([100-emp[order[i]], emp[order[i]]], colors=colors, startangle=90,
#                   wedgeprops={'width': 1.5})
#         # Highlight the variable of interest in the center
#         center_circle = plt.Circle((0, 0), 0.62, color=facecolor)
#         ax[i].add_artist(center_circle)
#          # Add the corresponding percentage text in the center
#         ax[i].text(0, 0, f'{pct: .2f}%', va='center', ha='center', fontsize=18,
#                     font=t_font, fontweight='bold', color=off_white)

#     # Wins% Label
#     h_axs(ax=ax[0], x=-.16, y=-.15, s='<Win %>', color=off_white, 
#           highlight_textprops=[{'color':plot_color}], font=b_font,
#           fontsize=b_fsize, fontweight='bold', zorder=2)
#     # Draws% Label
#     h_axs(ax=ax[1], x=-.16, y=-.15, s='<Draw %>', color=off_white,
#           highlight_textprops=[{'color':plot_color}], font=b_font,
#           fontsize=b_fsize, fontweight='bold', zorder=2) 
#     # Loss% Label
#     h_axs(ax=ax[2], x=-.16, y=-.15, s='<Loss %>', color=off_white,
#           highlight_textprops=[{'color':plot_color}], font=b_font,
#           fontsize=b_fsize, fontweight='bold', zorder=2)

#     # Title Text
#     title = f"{team} <FT MATCH RESULTS> AGAINST {select_opponent.upper()} IN ALL COMPS"
#     # Set titles for the figure and the subplot respectively
#     h_fig(x=.14, y=1.18, s=title, color=off_white, highlight_textprops=[{'color':plot_color}],
#            font=t_font, fontsize=t_fsize, fontweight='bold', zorder=2)

#     # FT Results Breakdown
#     txt = (f"<Games Played:> {len(plot_df)}  <| Wins:> {num_wins}" 
#            f" <| Draws:> {num_draws}  <| Loss:> {num_loss}")

#     h_fig(x=.22, y=-.08, s=txt, color=off_white, highlight_textprops=[ {'color':plot_color}, 
#                                                                        {'color':plot_color},
#                                                                        {'color':plot_color},
#                                                                        {'color':plot_color}],
#            font=t_font, fontsize=t_fsize, fontweight='bold', zorder=2)

#     # Endnotes
#     endnote_text = f"{display_msg}" 

#     endnote = fig.text(x=0.51, y= -.38, s=endnote_text, color=off_white, linespacing= 2,
#                        ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

#     # Name Text
#     name_text = fig.text(x=0.51, y= -.55, s=author, ha='center', va='center', 
#                        font=b_font, color=plot_color, alpha=.3, fontsize=b_fsize, zorder=2)

#     # Path Effects for texts
#     import matplotlib.patheffects as path_effects
#     endnote.set_path_effects([path_effects.Stroke(linewidth=.018, foreground=off_white),
#                               path_effects.Normal()])
#     name_text.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=plot_color), 
#                                 path_effects.Normal()])

#     # Figure Paddings         
#     pad_top = "\n\n"
#     pad_end = "\n\n"

#     fig.text(x=0.19, y= 1.20, s=pad_top, color=off_white, linespacing= 2,
#                     ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

#     fig.text(x=0.51, y= -.50, s=pad_end, color=off_white, linespacing= 2,
#                     ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

#     # Save and display
#     plt.savefig(f'{title}.png', dpi=1000, bbox_inches = "tight")
#     plt.show();

# %%
select_opponent = "AAUA"

plot_df = results_df[(results_df.HomeTeam == select_opponent) | (results_df.AwayTeam == select_opponent)]

order = ['W','D','L']
outcomes_vs_team = plot_df.FTR.value_counts().loc[order].reset_index()

record_dict = {}
for i in range(len(outcomes_vs_team)):
    record_dict[outcomes_vs_team['index'][i]] = outcomes_vs_team.FTR[i]

# Format response String    
record_vs_opp = f"W{record_dict['W']} D{record_dict['W']} L{record_dict['L']}"
total_meetings = len(plot_df)

# input variables
team = 'OAU'

# Display Message
display_msg = f"In {total_meetings} meetings against {opponent}, Team {team} has this record: {record_vs_opp}"

# ## PLOT TO RETURN FOR THE RECORD AGAINST THE OPPONENT
# # Order of Results
# order = ['W', 'D', 'L']

# # Data for the donut chart
# total_meetings = plot_df.FTR.sum()

# #  Setting up Figure & Axes
# fig, ax = plt.subplots(1,3, figsize=(12, 4), facecolor=facecolor, layout='constrained')

# # dictionary to access the contents of ftr
# emp = {}
# for i in range(len(plot_df)):             #Cannot put this block of code in the second for loop because   
# emp[plot_df['index'][i]] = plot_df.FTR[i] #we need to fill the dctionary first before trying to access it.


# for i in range(len(plot_df)):
# if order[i] == 'W':
#     colors = [plot_color, ax_color]off_white
#     num_wins = str(emp[order[i]])
# if order[i] == 'D':
#     colors = [ax_color, plot_color]
#     num_draws = str(emp[order[i]])
# if order[i] == 'L':
#     colors = [ax_color,plot_color]
#     num_loss = str(emp[order[i]])
# ax[i].set_yticks([])
# ax[i].set_xticks([])
# ax[i].set_facecolor(ax_color)
# ax[i].spines[['top','bottom','left','right']].set_visible(False)
# # Calculate % of that portion/selection
# pct = (emp[order[i]] / total_meetings) * 100 
# # Create the donut chart
# ax[i].pie([100-emp[order[i]], emp[order[i]]], colors=colors, startangle=90,
#           wedgeprops={'width': 1.5})
# # Highlight the variable of interest in the center
# center_circle = plt.Circle((0, 0), 0.62, color=facecolor)
# ax[i].add_artist(center_circle)
#  # Add the corresponding percentage text in the center
# ax[i].text(0, 0, f'{pct: .2f}%', va='center', ha='center', fontsize=18,
#             font=t_font, fontweight='bold', color=off_white)

# # Wins% Label
# h_axs(ax=ax[0], x=-.16, y=-.15, s='<Win %>', color=off_white, 
#   highlight_textprops=[{'color':plot_color}], font=b_font,
#   fontsize=b_fsize, fontweight='bold', zorder=2)
# # Draws% Label
# h_axs(ax=ax[1], x=-.16, y=-.15, s='<Draw %>', color=off_white,
#   highlight_textprops=[{'color':plot_color}], font=b_font,
#   fontsize=b_fsize, fontweight='bold', zorder=2) 
# # Loss% Label
# h_axs(ax=ax[2], x=-.16, y=-.15, s='<Loss %>', color=off_white,
#   highlight_textprops=[{'color':plot_color}], font=b_font,
#   fontsize=b_fsize, fontweight='bold', zorder=2)

# # Title Text
# title = f"{team} <FT MATCH RESULTS> AGAINST {select_opponent.upper()} IN ALL COMPS"
# # Set titles for the figure and the subplot respectively
# h_fig(x=.14, y=1.18, s=title, color=off_white, highlight_textprops=[{'color':plot_color}],
#    font=t_font, fontsize=t_fsize, fontweight='bold', zorder=2)

# # FT Results Breakdown
# txt = (f"<Games Played:> {len(plot_df)}  <| Wins:> {num_wins}" 
#    f" <| Draws:> {num_draws}  <| Loss:> {num_loss}")

# h_fig(x=.22, y=-.08, s=txt, color=off_white, highlight_textprops=[ {'color':plot_color}, 
#                                                                {'color':plot_color},
#                                                                {'color':plot_color},
#                                                                {'color':plot_color}],
#    font=t_font, fontsize=t_fsize, fontweight='bold', zorder=2)

# # Endnotes
# #     comps =
# endnote_text = f"{display_msg}"

# endnote = fig.text(x=0.51, y= -.38, s=endnote_text, color=off_white, linespacing= 2,
#                ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

# # Name Text
# name_text = fig.text(x=0.51, y= -.55, s=author, ha='center', va='center', 
#                font=b_font, color=plot_color, alpha=.3, fontsize=b_fsize, zorder=2)

# # Path Effects for texts
# import matplotlib.patheffects as path_effects
# endnote.set_path_effects([path_effects.Stroke(linewidth=.018, foreground=off_white),
#                       path_effects.Normal()])
# name_text.set_path_effects([path_effects.Stroke(linewidth=.005, foreground=plot_color), 
#                         path_effects.Normal()])

# # Figure Paddings         
# pad_top = "\n\n"
# pad_end = "\n\n"

# fig.text(x=0.19, y= 1.20, s=pad_top, color=off_white, linespacing= 2,
#             ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

# fig.text(x=0.51, y= -.50, s=pad_end, color=off_white, linespacing= 2,
#             ha='center', va='center', font=b_font, fontsize=b_fsize, zorder=2)

# # Save and display
# plt.savefig(f'{title}.png', dpi=1000, bbox_inches = "tight")
# plt.show();

# %%
total_meetings
display_msg
record_vs_opp 
# record_dict
# outcomes_vs_team
# plot_df
# Out:
# 4
# 'In 4 meetings against UNILORIN, Team OAU has this record: W1 D1 L0'
# 'W1 D1 L0'

# %% [markdown]
# ##### STREAK COUNT ------ FINAL ANALYSIS
# -- HT Streak
# -- SHR Streak
# -- FT Streak

# %% [markdown]
# ###### DID YOU KNOW (DYKs)?
# - OAU once won a NUGA Silver medal scoring just one goal the entire tournament. The team also conceeded one goal in the entire tournament and finished with a gd of 0.
# - 2-0 defeat to EKSU at HiFL 2022 ended an unbeaten run of 20 games in all comps.
# - Only ever lost bsck-to-back games twice in the course of 2003-2022
# - NUGA 2022 HT Draw vs UI was the first time OAU wasn't winning at HT against them since 2018 and the first HT Draw since 2011
# - NUGA 2011 in Uniben was the only NUGA Event OAU attended under Chike and didn't play in the Finals courtesy of second-half collapse by the teams in the group stage.
# - OAU has only ever suffered consecutive losses twice in their history**

# %% [markdown]
# # Duplicate
# - Total Tournaments Attended? Games Played? Games Won? Games Lost? Games Drawn?
# - Worst/Best Finish Per Tournament?
# - Win%
# - Home Win%
# - Away or Neutral Win%
# - Games won when leading/drawing/losing at halftime
# - Games Per Year? Wins/Draws/Loss Per Year?
# - Games Per Competition
